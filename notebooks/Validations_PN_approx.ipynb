# %% [markdown]
# Importing the saved data

# %%
import pickle

with open('saved_data/convergence_r_data_s1_r38_N10000.pkl', 'rb') as f:
    convergence_values_new_s1 = pickle.load(f)
    
with open('saved_data/convergence_r_data_s05_r38_N10000.pkl', 'rb') as f:
    convergence_values_new_s05 = pickle.load(f)
    
with open('saved_data/convergence_r_data_s02_r38_N10000.pkl', 'rb') as f:
    convergence_values_new_s02 = pickle.load(f)
    
with open('saved_data/convergence_r_data_s01_r38_N10000.pkl', 'rb') as f:
    convergence_values_new_s01 = pickle.load(f)  
    
with open('saved_data/convergence_r_data_norm_old.pkl', 'rb') as f:
    convergence_values_old = pickle.load(f)

# %% [markdown]
# saving values in arrays to be plotted

# %%
import numpy as np
import matplotlib.pyplot as plt

s_values = [0.1, 0.5, 1]
r_values = [1, 2, 4, 6, 8, 10, 20, 40, 80, 100, 200, 300, 400, 500]  # Vary r values as needed
q_fixed = 1  # Set your fixed q value here

params = ["bracket_theta", "bracket_omega"]

theta_s1_p5 = []
omega_s1_p5 = []

theta_s1_p50 = []
omega_s1_p50 = []

theta_s1_p95 = []
omega_s1_p95 = []

theta_s05_p5 = []
omega_s05_p5 = []

theta_s05_p50 = []
omega_s05_p50 = []

theta_s05_p95 = []
omega_s05_p95 = []

theta_s01_p5 = []
omega_s01_p5 = []

theta_s01_p50 = []
omega_s01_p50 = []

theta_s01_p95 = []
omega_s01_p95 = []


for r in r_values:
    for s in s_values:
        for param in params:
            if s==1 and param == "bracket_theta":
                theta_s1_p5.append(convergence_values_old[s][r][param]['p5'])
                theta_s1_p50.append(convergence_values_old[s][r][param]['p50'])
                theta_s1_p95.append(convergence_values_old[s][r][param]['p95'])
            elif s==1 and param == "bracket_omega":
                omega_s1_p5.append(convergence_values_old[s][r][param]['p5'])
                omega_s1_p50.append(convergence_values_old[s][r][param]['p50'])
                omega_s1_p95.append(convergence_values_old[s][r][param]['p95'])
            elif s==0.5 and param == "bracket_theta":
                theta_s05_p5.append(convergence_values_old[s][r][param]['p5'])
                theta_s05_p50.append(convergence_values_old[s][r][param]['p50'])
                theta_s05_p95.append(convergence_values_old[s][r][param]['p95'])
            elif s==0.5 and param == "bracket_omega":
                omega_s05_p5.append(convergence_values_old[s][r][param]['p5'])
                omega_s05_p50.append(convergence_values_old[s][r][param]['p50'])
                omega_s05_p95.append(convergence_values_old[s][r][param]['p95'])
            elif s==0.1 and param == "bracket_theta":
                theta_s01_p5.append(convergence_values_old[s][r][param]['p5'])
                theta_s01_p50.append(convergence_values_old[s][r][param]['p50'])
                theta_s01_p95.append(convergence_values_old[s][r][param]['p95'])
            elif s==0.1 and param == "bracket_omega":
                omega_s01_p5.append(convergence_values_old[s][r][param]['p5'])
                omega_s01_p50.append(convergence_values_old[s][r][param]['p50'])
                omega_s01_p95.append(convergence_values_old[s][r][param]['p95'])
            else:
                print("Error in the code")

# %%
s_new_values = [0.1, 0.2, 0.5, 1]
r_new_arr = [2, 4, 6, 8, 10, 15, 20, 25, 30, 40, 50, 60, 70, 80, 90, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 6000, 7000, 8000, 9000, 10000]
q_fixed = 1  # Set your fixed q value here

params = ["theta", "omega"]

theta_s1_p5_new = []
omega_s1_p5_new = []

theta_s1_p50_new = []
omega_s1_p50_new = []

theta_s1_p95_new = []
omega_s1_p95_new = []

theta_s05_p5_new = []
omega_s05_p5_new = []

theta_s05_p50_new = []
omega_s05_p50_new = []

theta_s05_p95_new = []
omega_s05_p95_new = []

theta_s02_p5_new = []
omega_s02_p5_new = []

theta_s02_p50_new = []
omega_s02_p50_new = []

theta_s02_p95_new = []
omega_s02_p95_new = []

theta_s01_p5_new = []
omega_s01_p5_new = []

theta_s01_p50_new = []
omega_s01_p50_new = []

theta_s01_p95_new = []
omega_s01_p95_new = []

for s in s_new_values:
    iteration = 0
    for r in r_new_arr:
        for param in params:
            if s==1 and param == "theta":
                theta_s1_p5_new.append(np.percentile(np.array(convergence_values_new_s1[param][iteration]).flatten(), 5))
                theta_s1_p50_new.append(np.percentile(np.array(convergence_values_new_s1[param][iteration]).flatten(), 50))
                theta_s1_p95_new.append(np.percentile(np.array(convergence_values_new_s1[param][iteration]).flatten(), 95))
            elif s==1 and param == "omega":
                omega_s1_p5_new.append(np.percentile(np.array(convergence_values_new_s1[param][iteration]).flatten(), 5))
                omega_s1_p50_new.append(np.percentile(np.array(convergence_values_new_s1[param][iteration]).flatten(), 50))
                omega_s1_p95_new.append(np.percentile(np.array(convergence_values_new_s1[param][iteration]).flatten(), 95))
            elif s==0.5 and param == "theta":
                theta_s05_p5_new.append(np.percentile(np.array(convergence_values_new_s05[param][iteration]).flatten(), 5))
                theta_s05_p50_new.append(np.percentile(np.array(convergence_values_new_s05[param][iteration]).flatten(), 50))
                theta_s05_p95_new.append(np.percentile(np.array(convergence_values_new_s05[param][iteration]).flatten(), 95))
            elif s==0.5 and param == "omega":
                omega_s05_p5_new.append(np.percentile(np.array(convergence_values_new_s05[param][iteration]).flatten(), 5))
                omega_s05_p50_new.append(np.percentile(np.array(convergence_values_new_s05[param][iteration]).flatten(), 50))
                omega_s05_p95_new.append(np.percentile(np.array(convergence_values_new_s05[param][iteration]).flatten(), 95))
            elif s==0.2 and param == "theta":
                theta_s02_p5_new.append(np.percentile(np.array(convergence_values_new_s02[param][iteration]).flatten(), 5))
                theta_s02_p50_new.append(np.percentile(np.array(convergence_values_new_s02[param][iteration]).flatten(), 50))
                theta_s02_p95_new.append(np.percentile(np.array(convergence_values_new_s02[param][iteration]).flatten(), 95))
            elif s==0.2 and param == "omega":
                omega_s02_p5_new.append(np.percentile(np.array(convergence_values_new_s02[param][iteration]).flatten(), 5))
                omega_s02_p50_new.append(np.percentile(np.array(convergence_values_new_s02[param][iteration]).flatten(), 50))
                omega_s02_p95_new.append(np.percentile(np.array(convergence_values_new_s02[param][iteration]).flatten(), 95))
            elif s==0.1 and param == "theta":
                theta_s01_p5_new.append(np.percentile(np.array(convergence_values_new_s01[param][iteration]).flatten(), 5))
                theta_s01_p50_new.append(np.percentile(np.array(convergence_values_new_s01[param][iteration]).flatten(), 50))
                theta_s01_p95_new.append(np.percentile(np.array(convergence_values_new_s01[param][iteration]).flatten(), 95))
            elif s==0.1 and param == "omega":
                omega_s01_p5_new.append(np.percentile(np.array(convergence_values_new_s01[param][iteration]).flatten(), 5))
                omega_s01_p50_new.append(np.percentile(np.array(convergence_values_new_s01[param][iteration]).flatten(), 50))
                omega_s01_p95_new.append(np.percentile(np.array(convergence_values_new_s01[param][iteration]).flatten(), 95))
            else:
                print("Error in the code")
        iteration += 1

# %% [markdown]
# a few edits -

# %%
r_array_edit = [1, 2, 4, 6, 8, 10, 20, 40, 80, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]

theta_s1_p50_edit_new = []
theta_s1_p5_edit_new = []
theta_s1_p95_edit_new = []

theta_s05_p50_edit_new = []
theta_s05_p5_edit_new = []
theta_s05_p95_edit_new = []

theta_s01_p50_edit_new = []
theta_s01_p5_edit_new = []
theta_s01_p95_edit_new = []

iter = 0
for r in r_values:
    theta_s1_p5_edit_new.append(theta_s1_p5[iter])
    theta_s1_p50_edit_new.append(theta_s1_p50[iter])
    theta_s1_p95_edit_new.append(theta_s1_p95[iter])
    
    theta_s05_p5_edit_new.append(theta_s05_p5[iter])
    theta_s05_p50_edit_new.append(theta_s05_p50[iter])
    theta_s05_p95_edit_new.append(theta_s05_p95[iter])
    
    theta_s01_p5_edit_new.append(theta_s01_p5[iter])
    theta_s01_p50_edit_new.append(theta_s01_p50[iter])
    theta_s01_p95_edit_new.append(theta_s01_p95[iter])
    
    iter += 1
    

theta_s1_p5_edit_new.append([theta_s1_p5_new[np.array(np.where(np.array(r_new_arr) == 600)).flatten()[0]]])
theta_s1_p50_edit_new.append([theta_s1_p50_new[np.array(np.where(np.array(r_new_arr) == 600)).flatten()[0]]])
theta_s1_p95_edit_new.append([theta_s1_p95_new[np.array(np.where(np.array(r_new_arr) == 600)).flatten()[0]]])

theta_s05_p5_edit_new.append([theta_s05_p5_new[np.array(np.where(np.array(r_new_arr) == 600)).flatten()[0]]])
theta_s05_p50_edit_new.append([theta_s05_p50_new[np.array(np.where(np.array(r_new_arr) == 600)).flatten()[0]]])
theta_s05_p95_edit_new.append([theta_s05_p95_new[np.array(np.where(np.array(r_new_arr) == 600)).flatten()[0]]])

theta_s01_p5_edit_new.append([theta_s01_p5_new[np.array(np.where(np.array(r_new_arr) == 600)).flatten()[0]]])
theta_s01_p50_edit_new.append([theta_s01_p50_new[np.array(np.where(np.array(r_new_arr) == 600)).flatten()[0]]])
theta_s01_p95_edit_new.append([theta_s01_p95_new[np.array(np.where(np.array(r_new_arr) == 600)).flatten()[0]]])

theta_s1_p5_edit_new.append([theta_s1_p5_new[np.array(np.where(np.array(r_new_arr) == 700)).flatten()[0]]])
theta_s1_p50_edit_new.append([theta_s1_p50_new[np.array(np.where(np.array(r_new_arr) == 700)).flatten()[0]]])
theta_s1_p95_edit_new.append([theta_s1_p95_new[np.array(np.where(np.array(r_new_arr) == 700)).flatten()[0]]])

theta_s05_p5_edit_new.append([theta_s05_p5_new[np.array(np.where(np.array(r_new_arr) == 700)).flatten()[0]]])
theta_s05_p50_edit_new.append([theta_s05_p50_new[np.array(np.where(np.array(r_new_arr) == 700)).flatten()[0]]])
theta_s05_p95_edit_new.append([theta_s05_p95_new[np.array(np.where(np.array(r_new_arr) == 700)).flatten()[0]]])

theta_s01_p5_edit_new.append([theta_s01_p5_new[np.array(np.where(np.array(r_new_arr) == 700)).flatten()[0]]])
theta_s01_p50_edit_new.append([theta_s01_p50_new[np.array(np.where(np.array(r_new_arr) == 700)).flatten()[0]]])
theta_s01_p95_edit_new.append([theta_s01_p95_new[np.array(np.where(np.array(r_new_arr) == 700)).flatten()[0]]])

theta_s1_p5_edit_new.append([theta_s1_p5_new[np.array(np.where(np.array(r_new_arr) == 800)).flatten()[0]]])
theta_s1_p50_edit_new.append([theta_s1_p50_new[np.array(np.where(np.array(r_new_arr) == 800)).flatten()[0]]])
theta_s1_p95_edit_new.append([theta_s1_p95_new[np.array(np.where(np.array(r_new_arr) == 800)).flatten()[0]]])

theta_s05_p5_edit_new.append([theta_s05_p5_new[np.array(np.where(np.array(r_new_arr) == 800)).flatten()[0]]])
theta_s05_p50_edit_new.append([theta_s05_p50_new[np.array(np.where(np.array(r_new_arr) == 800)).flatten()[0]]])
theta_s05_p95_edit_new.append([theta_s05_p95_new[np.array(np.where(np.array(r_new_arr) == 800)).flatten()[0]]])

theta_s01_p5_edit_new.append([theta_s01_p5_new[np.array(np.where(np.array(r_new_arr) == 800)).flatten()[0]]])
theta_s01_p50_edit_new.append([theta_s01_p50_new[np.array(np.where(np.array(r_new_arr) == 800)).flatten()[0]]])
theta_s01_p95_edit_new.append([theta_s01_p95_new[np.array(np.where(np.array(r_new_arr) == 800)).flatten()[0]]])

theta_s1_p5_edit_new.append([theta_s1_p5_new[np.array(np.where(np.array(r_new_arr) == 900)).flatten()[0]]])
theta_s1_p50_edit_new.append([theta_s1_p50_new[np.array(np.where(np.array(r_new_arr) == 900)).flatten()[0]]])
theta_s1_p95_edit_new.append([theta_s1_p95_new[np.array(np.where(np.array(r_new_arr) == 900)).flatten()[0]]])

theta_s05_p5_edit_new.append([theta_s05_p5_new[np.array(np.where(np.array(r_new_arr) == 900)).flatten()[0]]])
theta_s05_p50_edit_new.append([theta_s05_p50_new[np.array(np.where(np.array(r_new_arr) == 900)).flatten()[0]]])
theta_s05_p95_edit_new.append([theta_s05_p95_new[np.array(np.where(np.array(r_new_arr) == 900)).flatten()[0]]])

theta_s01_p5_edit_new.append([theta_s01_p5_new[np.array(np.where(np.array(r_new_arr) == 900)).flatten()[0]]])
theta_s01_p50_edit_new.append([theta_s01_p50_new[np.array(np.where(np.array(r_new_arr) == 900)).flatten()[0]]])
theta_s01_p95_edit_new.append([theta_s01_p95_new[np.array(np.where(np.array(r_new_arr) == 900)).flatten()[0]]])

theta_s1_p5_edit_new.append([theta_s1_p5_new[np.array(np.where(np.array(r_new_arr) == 1000)).flatten()[0]]])
theta_s1_p50_edit_new.append([theta_s1_p50_new[np.array(np.where(np.array(r_new_arr) == 1000)).flatten()[0]]])
theta_s1_p95_edit_new.append([theta_s1_p95_new[np.array(np.where(np.array(r_new_arr) == 1000)).flatten()[0]]])

theta_s05_p5_edit_new.append([theta_s05_p5_new[np.array(np.where(np.array(r_new_arr) == 1000)).flatten()[0]]])
theta_s05_p50_edit_new.append([theta_s05_p50_new[np.array(np.where(np.array(r_new_arr) == 1000)).flatten()[0]]])
theta_s05_p95_edit_new.append([theta_s05_p95_new[np.array(np.where(np.array(r_new_arr) == 1000)).flatten()[0]]])

theta_s01_p5_edit_new.append([theta_s01_p5_new[np.array(np.where(np.array(r_new_arr) == 1000)).flatten()[0]]])
theta_s01_p50_edit_new.append([theta_s01_p50_new[np.array(np.where(np.array(r_new_arr) == 1000)).flatten()[0]]])
theta_s01_p95_edit_new.append([theta_s01_p95_new[np.array(np.where(np.array(r_new_arr) == 1000)).flatten()[0]]])

# %%
omega_s1_p50_edit_new = []
omega_s1_p5_edit_new = []
omega_s1_p95_edit_new = []

omega_s05_p50_edit_new = []
omega_s05_p5_edit_new = []
omega_s05_p95_edit_new = []

omega_s01_p50_edit_new = []
omega_s01_p5_edit_new = []
omega_s01_p95_edit_new = []

iter = 0
for r in r_values:
    omega_s1_p5_edit_new.append(omega_s1_p5[iter])
    omega_s1_p50_edit_new.append(omega_s1_p50[iter])
    omega_s1_p95_edit_new.append(omega_s1_p95[iter])
    
    omega_s05_p5_edit_new.append(omega_s05_p5[iter])
    omega_s05_p50_edit_new.append(omega_s05_p50[iter])
    omega_s05_p95_edit_new.append(omega_s05_p95[iter])
    
    omega_s01_p5_edit_new.append(omega_s01_p5[iter])
    omega_s01_p50_edit_new.append(omega_s01_p50[iter])
    omega_s01_p95_edit_new.append(omega_s01_p95[iter])
    
    iter += 1
    
omega_s1_p5_edit_new.append([omega_s1_p5_new[np.array(np.where(np.array(r_new_arr) == 600)).flatten()[0]]])
omega_s1_p50_edit_new.append([omega_s1_p50_new[np.array(np.where(np.array(r_new_arr) == 600)).flatten()[0]]])
omega_s1_p95_edit_new.append([omega_s1_p95_new[np.array(np.where(np.array(r_new_arr) == 600)).flatten()[0]]])

omega_s05_p5_edit_new.append([omega_s05_p5_new[np.array(np.where(np.array(r_new_arr) == 600)).flatten()[0]]])
omega_s05_p50_edit_new.append([omega_s05_p50_new[np.array(np.where(np.array(r_new_arr) == 600)).flatten()[0]]])
omega_s05_p95_edit_new.append([omega_s05_p95_new[np.array(np.where(np.array(r_new_arr) == 600)).flatten()[0]]])

omega_s01_p5_edit_new.append([omega_s01_p5_new[np.array(np.where(np.array(r_new_arr) == 600)).flatten()[0]]])
omega_s01_p50_edit_new.append([omega_s01_p50_new[np.array(np.where(np.array(r_new_arr) == 600)).flatten()[0]]])
omega_s01_p95_edit_new.append([omega_s01_p95_new[np.array(np.where(np.array(r_new_arr) == 600)).flatten()[0]]])

omega_s1_p5_edit_new.append([omega_s1_p5_new[np.array(np.where(np.array(r_new_arr) == 700)).flatten()[0]]])
omega_s1_p50_edit_new.append([omega_s1_p50_new[np.array(np.where(np.array(r_new_arr) == 700)).flatten()[0]]])
omega_s1_p95_edit_new.append([omega_s1_p95_new[np.array(np.where(np.array(r_new_arr) == 700)).flatten()[0]]])

omega_s05_p5_edit_new.append([omega_s05_p5_new[np.array(np.where(np.array(r_new_arr) == 700)).flatten()[0]]])
omega_s05_p50_edit_new.append([omega_s05_p50_new[np.array(np.where(np.array(r_new_arr) == 700)).flatten()[0]]])
omega_s05_p95_edit_new.append([omega_s05_p95_new[np.array(np.where(np.array(r_new_arr) == 700)).flatten()[0]]])

omega_s01_p5_edit_new.append([omega_s01_p5_new[np.array(np.where(np.array(r_new_arr) == 700)).flatten()[0]]])
omega_s01_p50_edit_new.append([omega_s01_p50_new[np.array(np.where(np.array(r_new_arr) == 700)).flatten()[0]]])
omega_s01_p95_edit_new.append([omega_s01_p95_new[np.array(np.where(np.array(r_new_arr) == 700)).flatten()[0]]])

omega_s1_p5_edit_new.append([omega_s1_p5_new[np.array(np.where(np.array(r_new_arr) == 800)).flatten()[0]]])
omega_s1_p50_edit_new.append([omega_s1_p50_new[np.array(np.where(np.array(r_new_arr) == 800)).flatten()[0]]])
omega_s1_p95_edit_new.append([omega_s1_p95_new[np.array(np.where(np.array(r_new_arr) == 800)).flatten()[0]]])

omega_s05_p5_edit_new.append([omega_s05_p5_new[np.array(np.where(np.array(r_new_arr) == 800)).flatten()[0]]])
omega_s05_p50_edit_new.append([omega_s05_p50_new[np.array(np.where(np.array(r_new_arr) == 800)).flatten()[0]]])
omega_s05_p95_edit_new.append([omega_s05_p95_new[np.array(np.where(np.array(r_new_arr) == 800)).flatten()[0]]])

omega_s01_p5_edit_new.append([omega_s01_p5_new[np.array(np.where(np.array(r_new_arr) == 800)).flatten()[0]]])
omega_s01_p50_edit_new.append([omega_s01_p50_new[np.array(np.where(np.array(r_new_arr) == 800)).flatten()[0]]])
omega_s01_p95_edit_new.append([omega_s01_p95_new[np.array(np.where(np.array(r_new_arr) == 800)).flatten()[0]]])

omega_s1_p5_edit_new.append([omega_s1_p5_new[np.array(np.where(np.array(r_new_arr) == 900)).flatten()[0]]])
omega_s1_p50_edit_new.append([omega_s1_p50_new[np.array(np.where(np.array(r_new_arr) == 900)).flatten()[0]]])
omega_s1_p95_edit_new.append([omega_s1_p95_new[np.array(np.where(np.array(r_new_arr) == 900)).flatten()[0]]])

omega_s05_p5_edit_new.append([omega_s05_p5_new[np.array(np.where(np.array(r_new_arr) == 900)).flatten()[0]]])
omega_s05_p50_edit_new.append([omega_s05_p50_new[np.array(np.where(np.array(r_new_arr) == 900)).flatten()[0]]])
omega_s05_p95_edit_new.append([omega_s05_p95_new[np.array(np.where(np.array(r_new_arr) == 900)).flatten()[0]]])

omega_s01_p5_edit_new.append([omega_s01_p5_new[np.array(np.where(np.array(r_new_arr) == 900)).flatten()[0]]])
omega_s01_p50_edit_new.append([omega_s01_p50_new[np.array(np.where(np.array(r_new_arr) == 900)).flatten()[0]]])
omega_s01_p95_edit_new.append([omega_s01_p95_new[np.array(np.where(np.array(r_new_arr) == 900)).flatten()[0]]])

omega_s1_p5_edit_new.append([omega_s1_p5_new[np.array(np.where(np.array(r_new_arr) == 1000)).flatten()[0]]])
omega_s1_p50_edit_new.append([omega_s1_p50_new[np.array(np.where(np.array(r_new_arr) == 1000)).flatten()[0]]])
omega_s1_p95_edit_new.append([omega_s1_p95_new[np.array(np.where(np.array(r_new_arr) == 1000)).flatten()[0]]])

omega_s05_p5_edit_new.append([omega_s05_p5_new[np.array(np.where(np.array(r_new_arr) == 1000)).flatten()[0]]])
omega_s05_p50_edit_new.append([omega_s05_p50_new[np.array(np.where(np.array(r_new_arr) == 1000)).flatten()[0]]])    
omega_s05_p95_edit_new.append([omega_s05_p95_new[np.array(np.where(np.array(r_new_arr) == 1000)).flatten()[0]]])

omega_s01_p5_edit_new.append([omega_s01_p5_new[np.array(np.where(np.array(r_new_arr) == 1000)).flatten()[0]]])
omega_s01_p50_edit_new.append([omega_s01_p50_new[np.array(np.where(np.array(r_new_arr) == 1000)).flatten()[0]]])
omega_s01_p95_edit_new.append([omega_s01_p95_new[np.array(np.where(np.array(r_new_arr) == 1000)).flatten()[0]]])

# %% [markdown]
# Also, we can talk about the values tabulated in Table 3 via calculating r at f = 20 Hz and taking the slice in the plot at that binary separation

# %%
solar_mass = 4.925490947671582e-06
def r_at_20_Hz(mcz_in_solar, q, f_ref = 20.0):
    eta = q/(1+q)**2
    total_mass = (eta**(-0.6))*mcz_in_solar*solar_mass
    r20 = ((np.pi*f_ref*total_mass)**(-2/3))
    return r20

# %% [markdown]
# Plots -

# %%
plt.figure(figsize=(5, 4))
import matplotlib
matplotlib.rcParams['figure.dpi'] = 400
r_array_edit = [1, 2, 4, 6, 8, 10, 20, 40, 80, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
plt.plot(r_array_edit, theta_s1_p50_edit_new, label=r"$\chi_1 = \chi_2 = 1$", color="green", linewidth=2.0)
plt.plot(r_array_edit, theta_s1_p5_edit_new, color="green", linestyle="--")
plt.plot(r_array_edit, theta_s1_p95_edit_new, color="green", linestyle="--")

plt.plot(r_array_edit, theta_s05_p50_edit_new, label=r"$\chi_1 = \chi_2 = 0.5$", color="blue", linewidth=2.0)
plt.plot(r_array_edit, theta_s05_p5_edit_new, color="blue", linestyle="--")
plt.plot(r_array_edit, theta_s05_p95_edit_new, color="blue", linestyle="--")

plt.plot(r_array_edit, theta_s01_p50_edit_new, label=r"$\chi_1 = \chi_2 = 0.1$", color="orange", linewidth=2.0)
plt.plot(r_array_edit, theta_s01_p5_edit_new, color="orange", linestyle="--")
plt.plot(r_array_edit, theta_s01_p95_edit_new, color="orange", linestyle="--")

plt.fill_between(r_array_edit, np.array(theta_s1_p5_edit_new).flatten(), np.array(theta_s1_p95_edit_new).flatten(), color="green", alpha=0.4)
plt.fill_between(r_array_edit, np.array(theta_s05_p5_edit_new).flatten(), np.array(theta_s05_p95_edit_new).flatten(), color="blue", alpha=0.4)
plt.fill_between(r_array_edit, np.array(theta_s01_p5_edit_new).flatten(), np.array(theta_s01_p95_edit_new).flatten(), color="red", alpha=0.4)

r_m20_q1 = r_at_20_Hz(20, 1, 20)
r_m10_q1 = r_at_20_Hz(10, 1, 20)
r_m40_q1 = r_at_20_Hz(40, 1, 20)

plt.axvline(x=r_m20_q1, color='green', linestyle=':', label=r'$r_{\rm 20\,Hz}$ for $M=20M_{\odot}$')
plt.axvline(x=r_m10_q1, color='green', linestyle='-.', label=r'$r_{\rm 20\,Hz}$ for $M=10M_{\odot}$')
#plt.axvline(x=r_m40_q1, color='green', linestyle='-.', label=r'$r_{\rm 20\,Hz}$ for $M=40M_{\odot}$')

plt.xlabel(r'$r/M$', fontsize=18)
plt.ylabel(r'$\tilde{\theta}$', fontsize=18)
plt.xscale('log')
plt.xlim(6, 1000)
plt.grid()

fig = plt.gcf()
fig.savefig('figs/validation_theta_tilde_s1_05_01.pdf', format='pdf', bbox_inches = 'tight')

# %%
plt.figure(figsize=(5, 4))
plt.plot(r_array_edit, omega_s1_p50_edit_new, label=r"$\chi_1 = \chi_2 = 1$", color="green", linewidth=2.0)
plt.plot(r_array_edit, omega_s1_p5_edit_new, color="green", linestyle="--")
plt.plot(r_array_edit, omega_s1_p95_edit_new, color="green", linestyle="--")

plt.plot(r_array_edit, omega_s05_p50_edit_new, label=r"$\chi_1 = \chi_2 = 0.5$", color="blue", linewidth=2.0)
plt.plot(r_array_edit, omega_s05_p5_edit_new, color="blue", linestyle="--")
plt.plot(r_array_edit, omega_s05_p95_edit_new, color="blue", linestyle="--")

plt.plot(r_array_edit, omega_s01_p50_edit_new, label=r"$\chi_1 = \chi_2 = 0.1$", color="orange", linewidth=2.0)
plt.plot(r_array_edit, omega_s01_p5_edit_new, color="orange", linestyle="--")
plt.plot(r_array_edit, omega_s01_p95_edit_new, color="orange", linestyle="--")

plt.fill_between(r_array_edit, np.array(omega_s1_p5_edit_new).flatten(), np.array(omega_s1_p95_edit_new).flatten(), color="green", alpha=0.4)
plt.fill_between(r_array_edit, np.array(omega_s05_p5_edit_new).flatten(), np.array(omega_s05_p95_edit_new).flatten(), color="blue", alpha=0.4)
plt.fill_between(r_array_edit, np.array(omega_s01_p5_edit_new).flatten(), np.array(omega_s01_p95_edit_new).flatten(), color="red", alpha=0.4)

plt.axvline(x=r_m20_q1, color='green', linestyle=':')#, label=r'$r_{\rm 20\,Hz}$ for $M=20M_{\odot}$')
plt.axvline(x=r_m10_q1, color='green', linestyle='-.')#, label=r'$r_{\rm 20\,Hz}$ for $M=10M_{\odot}$')
#plt.axvline(x=r_m40_q1, color='green', linestyle='-.')#, label=r'$r_{\rm 20\,Hz}$ for $M=40M_{\odot}$')

plt.xlabel(r'$r/M$', fontsize=18)
plt.ylabel(r'$\tilde{\Omega}$', fontsize=18)
plt.xscale('log')
plt.xlim(6, 1000)
plt.legend(loc = 'upper right', fontsize=14, framealpha=0.95)
plt.grid()

plt.ylim(1.4, 2.6)
fig = plt.gcf()
fig.savefig('figs/validation_omega_tilde_s1_05_01.pdf', format='pdf', bbox_inches = 'tight')

# %%
with open('saved_data/convergence_r_data_q0105.pkl', 'rb') as f:
    convergence_values_new_q0105 = pickle.load(f)
    
r_arr_new = convergence_values_new_q0105['r']

# %%
p5_theta_tilde_q01_new = convergence_values_new_q0105['q01']['theta']['p5']
p50_theta_tilde_q01_new = convergence_values_new_q0105['q01']['theta']['p50']
p95_theta_tilde_q01_new = convergence_values_new_q0105['q01']['theta']['p95']

p5_omega_tilde_q01_new = convergence_values_new_q0105['q01']['Omega']['p5']
p50_omega_tilde_q01_new = convergence_values_new_q0105['q01']['Omega']['p50']
p95_omega_tilde_q01_new = convergence_values_new_q0105['q01']['Omega']['p95']

p5_theta_tilde_q05_new = convergence_values_new_q0105['q05']['theta']['p5']
p50_theta_tilde_q05_new = convergence_values_new_q0105['q05']['theta']['p50']
p95_theta_tilde_q05_new = convergence_values_new_q0105['q05']['theta']['p95']

p5_omega_tilde_q05_new = convergence_values_new_q0105['q05']['Omega']['p5']
p50_omega_tilde_q05_new = convergence_values_new_q0105['q05']['Omega']['p50']
p95_omega_tilde_q05_new = convergence_values_new_q0105['q05']['Omega']['p95']

# %%
plt.figure(figsize=(5, 4))

plt.plot(r_arr_new, p5_theta_tilde_q01_new, color = 'green', linestyle = '--')
plt.plot(r_arr_new, p50_theta_tilde_q01_new, color = 'green', linestyle = '-', linewidth = 2,label = r'$q = 0.1$')
plt.plot(r_arr_new, p95_theta_tilde_q01_new, color = 'green', linestyle = '--')

plt.plot(r_arr_new, p5_theta_tilde_q05_new, color = 'blue', linestyle = '--')
plt.plot(r_arr_new, p50_theta_tilde_q05_new, color = 'blue', linestyle = '-', linewidth = 2, label = r'$q = 0.5$')
plt.plot(r_arr_new, p95_theta_tilde_q05_new, color = 'blue', linestyle = '--')

plt.fill_between(r_arr_new, p5_theta_tilde_q01_new, p95_theta_tilde_q01_new, color = 'green', alpha = 0.4)
plt.fill_between(r_arr_new, p5_theta_tilde_q05_new, p95_theta_tilde_q05_new, color = 'blue', alpha = 0.4)

plt.axhline(y = 10*np.pi, color='k')
plt.axvline(x = r_at_20_Hz(20, 0.1, 20), color='green', linestyle=':')#, label=r'r at 20 Hz for $\mathcal{M} = 20 M_{\odot}$ and $q = 0.1$')
plt.axvline(x = r_at_20_Hz(10, 0.1, 20), color='green', linestyle='-.')#, label=r'r at 20 Hz for $\mathcal{M} = 10 M_{\odot}$ and $q = 0.1$')

plt.axvline(x = r_at_20_Hz(10, 0.5, 20), color='b', linestyle='-.') #, label=r'r at 20 Hz for $\mathcal{M} = 20 M_{\odot}$ and $q = 1$')
plt.axvline(x = r_at_20_Hz(20, 0.5, 20), color='blue', linestyle=':')#, label=r'r at 20 Hz for $\mathcal{M} = 20 M_{\odot}$ and $q = 0.5$')

plt.legend(fontsize = 14, loc = 'upper right', framealpha = 0.95)
#plt.title(r'Precession Amplitude $\tilde{\theta}$ vs r')
plt.xlabel(r'$r/M$', fontsize = 18)
plt.ylabel(r'$\tilde{\theta}$', fontsize = 18)
plt.xscale('log')
plt.grid()
plt.xlim(6, 1000)

fig = plt.gcf()
fig.savefig('figs/validation_theta_tilde_q01_05.pdf', format='pdf', bbox_inches = 'tight')

# %%
plt.figure(figsize=(5, 4))
plt.plot(r_arr_new, p5_omega_tilde_q01_new, color = 'green', linestyle = '--')
plt.plot(r_arr_new, p50_omega_tilde_q01_new, color = 'green', linestyle = '-', linewidth = 2)#, label = r'$q = 0.1$')
plt.plot(r_arr_new, p95_omega_tilde_q01_new, color = 'green', linestyle = '--')

plt.plot(r_arr_new, p5_omega_tilde_q05_new, color = 'blue', linestyle = '--')
plt.plot(r_arr_new, p50_omega_tilde_q05_new, color = 'blue', linestyle = '-', linewidth = 2)#, label = r'$q = 0.5$')
plt.plot(r_arr_new, p95_omega_tilde_q05_new, color = 'blue', linestyle = '--')

plt.fill_between(r_arr_new, p5_omega_tilde_q01_new, p95_omega_tilde_q01_new, color = 'green', alpha = 0.4)
plt.fill_between(r_arr_new, p5_omega_tilde_q05_new, p95_omega_tilde_q05_new, color = 'blue', alpha = 0.4)

plt.axvline(x = r_at_20_Hz(20, 0.1, 20), color='green', linestyle=':', label=r'$r/M$ at $f_{\rm ref}$ for $\mathcal{M}$ = 20 $M_{\odot}$')
plt.axvline(x = r_at_20_Hz(10, 0.1, 20), color='green', linestyle='-.', label=r'$r/M$ at $f_{\rm ref}$ for $\mathcal{M}$ = 10 $M_{\odot}$')
#plt.axvline(x = r_at_20_Hz(20, 1, 20), color='b', linestyle=':', label=r'r at 20 Hz for $\mathcal{M} = 20 M_{\odot}$ and $q = 1$')
plt.axvline(x = r_at_20_Hz(20, 0.5, 20), color='blue', linestyle=':')#, label=r'$r/M$ at $f_{\rm ref}$ for $\mathcal{M}$ = 20 $M_{\odot}$')
plt.axvline(x = r_at_20_Hz(10, 0.5, 20), color='blue', linestyle='-.')

plt.legend(fontsize = 14, framealpha=0.95, loc = 'upper right')
#plt.title(r'Precession Amplitude $\tilde{\theta}$ vs r')
plt.xlabel(r'$r/M$', fontsize = 18)
plt.ylabel(r'$\tilde{\Omega}$', fontsize = 18)
plt.xscale('log')
plt.grid()
plt.ylim(0, 3)
plt.xlim(6, 1000)

fig = plt.gcf()
fig.savefig('figs/validation_omega_tilde_q01_05.pdf', format='pdf', bbox_inches = 'tight')

# %%
plt.figure(figsize=(5, 4))
plt.plot(r_array_edit, theta_s1_p5_edit_new, color="green", linestyle = '--')
plt.plot(r_array_edit, theta_s1_p50_edit_new, color="green", linestyle = '-', linewidth=2, label = r'$q = 1$')
plt.plot(r_array_edit, theta_s1_p95_edit_new, color="green", linestyle = '--')

plt.plot(r_arr_new, p5_theta_tilde_q05_new, color = 'blue', linestyle = '--')
plt.plot(r_arr_new, p50_theta_tilde_q05_new, color = 'blue', linestyle = '-', linewidth = 2, label = r'$q = 0.5$')
plt.plot(r_arr_new, p95_theta_tilde_q05_new, color = 'blue', linestyle = '--')

plt.plot(r_arr_new, p5_theta_tilde_q01_new, color = 'orange', linestyle = '--')
plt.plot(r_arr_new, p50_theta_tilde_q01_new, color = 'orange', linestyle = '-', linewidth = 2,label = r'$q = 0.1$')
plt.plot(r_arr_new, p95_theta_tilde_q01_new, color = 'orange', linestyle = '--')

plt.fill_between(r_array_edit, np.array(theta_s1_p5_edit_new).flatten(), np.array(theta_s1_p95_edit_new).flatten(), color="green", alpha=0.4)
plt.fill_between(r_arr_new, p5_theta_tilde_q05_new, p95_theta_tilde_q05_new, color = 'blue', alpha = 0.4)
plt.fill_between(r_arr_new, p5_theta_tilde_q01_new, p95_theta_tilde_q01_new, color = 'orange', alpha = 0.4)

plt.axhline(y = 10*np.pi, color='k')
plt.axvline(x = r_at_20_Hz(20, 0.1, 20), color='orange', linestyle=':')#, label=r'r at 20 Hz for $\mathcal{M} = 20 M_{\odot}$ and $q = 0.1$')
plt.axvline(x = r_at_20_Hz(10, 0.1, 20), color='orange', linestyle='-.')#, label=r'r at 20 Hz for $\mathcal{M} = 10 M_{\odot}$ and $q = 0.1$')
plt.axvline(x = r_at_20_Hz(20, 1, 20), color='green', linestyle=':')#, label=r'r at 20 Hz for $\mathcal{M} = 20 M_{\odot}$ and $q = 1$')
plt.axvline(x = r_at_20_Hz(10, 1, 20), color='green', linestyle='-.')#, label=r'r at 20 Hz for $\mathcal{M} = 10 M_{\odot}$ and $q = 1$')
#plt.axvline(x = r_at_20_Hz(40, 1, 20), color='green', linestyle='-')#, label=r'r at 20 Hz for $\mathcal{M} = 40 M_{\odot}$ and $q = 1$')
plt.axvline(x = r_at_20_Hz(20, 0.5, 20), color='blue', linestyle=':')#, label=r'r at 20 Hz for $\mathcal{M} = 20 M_{\odot}$ and $q = 0.5$')
plt.axvline(x = r_at_20_Hz(10, 0.5, 20), color='blue', linestyle='-.')#, label=r'r at 20 Hz for $\mathcal{M} = 10 M_{\odot}$ and $q = 0.5$')

plt.legend(fontsize = 10, loc = 'upper right', framealpha = 0.95)
#plt.title(r'Precession Amplitude $\tilde{\theta}$ vs r')
plt.xlabel(r'$r/M$', fontsize = 18)
plt.ylabel(r'$\tilde{\theta}$', fontsize = 18)
plt.xscale('log')
plt.grid()
plt.xlim(6, 1000)

fig = plt.gcf()
fig.savefig('figs/validation_theta_tilde_q01_05_1_sl.pdf', format='pdf', bbox_inches = 'tight')

# %%
plt.figure(figsize=(5, 4))
plt.plot(r_array_edit, omega_s1_p5_edit_new, color="green", linestyle = '--')
plt.plot(r_array_edit, omega_s1_p50_edit_new, color="green", linestyle = '-', linewidth=2)#, label = r'$q = 1$')
plt.plot(r_array_edit, omega_s1_p95_edit_new, color="green", linestyle = '--')

plt.plot(r_arr_new, p5_omega_tilde_q05_new, color = 'blue', linestyle = '--')
plt.plot(r_arr_new, p50_omega_tilde_q05_new, color = 'blue', linestyle = '-', linewidth = 2)#, label = r'$q = 0.5$')
plt.plot(r_arr_new, p95_omega_tilde_q05_new, color = 'blue', linestyle = '--')

plt.plot(r_arr_new, p5_omega_tilde_q01_new, color = 'orange', linestyle = '--')
plt.plot(r_arr_new, p50_omega_tilde_q01_new, color = 'orange', linestyle = '-', linewidth = 2)#, label = r'$q = 0.1$')
plt.plot(r_arr_new, p95_omega_tilde_q01_new, color = 'orange', linestyle = '--')

plt.fill_between(r_array_edit, np.array(omega_s1_p5_edit_new).flatten(), np.array(omega_s1_p95_edit_new).flatten(), color="green", alpha=0.4)
plt.fill_between(r_arr_new, p5_omega_tilde_q05_new, p95_omega_tilde_q05_new, color = 'blue', alpha = 0.4)
plt.fill_between(r_arr_new, p5_omega_tilde_q01_new, p95_omega_tilde_q01_new, color = 'orange', alpha = 0.4)


plt.axvline(x = r_at_20_Hz(20, 0.1, 20), color='orange', linestyle=':')#, label=r'r at 20 Hz for $\mathcal{M} = 20 M_{\odot}$ and $q = 0.1$')
plt.axvline(x = r_at_20_Hz(10, 0.1, 20), color='orange', linestyle='-.')#, label=r'r at 20 Hz for $\mathcal{M} = 10 M_{\odot}$ and $q = 0.1$')
plt.axvline(x = r_at_20_Hz(20, 1, 20), color='green', linestyle=':', label=r'$r/M$ at $f_{\rm ref}$ for $\mathcal{M}$ = 20 $M_{\odot}$')
plt.axvline(x = r_at_20_Hz(10, 1, 20), color='green', linestyle='-.', label=r'$r/M$ at $f_{\rm ref}$ for $\mathcal{M}$ = 10 $M_{\odot}$')
#plt.axvline(x = r_at_20_Hz(40, 1, 20), color='green', linestyle='-')#, label=r'r at 20 Hz for $\mathcal{M} = 40 M_{\odot}$ and $q = 1$')
plt.axvline(x = r_at_20_Hz(20, 0.5, 20), color='blue', linestyle=':')#, label=r'r at 20 Hz for $\mathcal{M} = 20 M_{\odot}$ and $q = 0.5$')
plt.axvline(x = r_at_20_Hz(10, 0.5, 20), color='blue', linestyle='-.')


plt.legend(fontsize = 10, loc = 'upper right', framealpha = 0.95)
#plt.title(r'Precession Amplitude $\tilde{\theta}$ vs r')
plt.xlabel(r'$r/M$', fontsize = 18)
plt.ylabel(r'$\tilde{\Omega}$', fontsize = 18)
plt.xscale('log')
plt.grid()
plt.ylim(0, 3)
plt.xlim(6, 1000)

fig = plt.gcf()
fig.savefig('figs/validation_omega_tilde_q01_05_1_sl.pdf', format='pdf', bbox_inches = 'tight')

# %%
plt.figure(figsize=(5, 4))

eta_01 = 0.1/(1+0.1)**2
eta_05 = 0.5/(1+0.5)**2

plt.plot(r_arr_new, np.array(p5_theta_tilde_q01_new)*(4*eta_01), color = 'green', linestyle = '--')
plt.plot(r_arr_new, np.array(p50_theta_tilde_q01_new)*4*eta_01, color = 'green', linestyle = '-', linewidth = 2,label = r'$q = 0.1$')
plt.plot(r_arr_new, np.array(p95_theta_tilde_q01_new)*4*eta_01, color = 'green', linestyle = '--')

plt.plot(r_arr_new, np.array(p5_theta_tilde_q05_new)*4*eta_05, color = 'blue', linestyle = '--')
plt.plot(r_arr_new, np.array(p50_theta_tilde_q05_new)*4*eta_05, color = 'blue', linestyle = '-', linewidth = 2, label = r'$q = 0.5$')
plt.plot(r_arr_new, np.array(p95_theta_tilde_q05_new)*4*eta_05, color = 'blue', linestyle = '--')

plt.fill_between(r_arr_new, np.array(p5_theta_tilde_q01_new)*4*eta_01, np.array(p95_theta_tilde_q01_new)*4*eta_01, color = 'green', alpha = 0.4)
plt.fill_between(r_arr_new, np.array(p5_theta_tilde_q05_new)*4*eta_05, np.array(p95_theta_tilde_q05_new)*4*eta_05, color = 'blue', alpha = 0.4)

plt.axhline(y = 10*np.pi, color='k')
plt.axvline(x = r_at_20_Hz(20, 0.1, 20), color='green', linestyle=':')#, label=r'r at 20 Hz for $\mathcal{M} = 20 M_{\odot}$ and $q = 0.1$')
plt.axvline(x = r_at_20_Hz(10, 0.1, 20), color='green', linestyle='-.')#, label=r'r at 20 Hz for $\mathcal{M} = 10 M_{\odot}$ and $q = 0.1$')

#plt.axvline(x = r_at_20_Hz(20, 1, 20), color='b', linestyle=':', label=r'r at 20 Hz for $\mathcal{M} = 20 M_{\odot}$ and $q = 1$')
plt.axvline(x = r_at_20_Hz(20, 0.5, 20), color='blue', linestyle=':')#, label=r'r at 20 Hz for $\mathcal{M} = 20 M_{\odot}$ and $q = 0.5$')
plt.axvline(x = r_at_20_Hz(10, 0.5, 20), color='blue', linestyle='-.')#, label=r'r at 20 Hz for $\mathcal{M} = 10 M_{\odot}$ and $q = 0.5$')

plt.legend(fontsize = 14, loc = 'upper right', framealpha = 0.95)
#plt.title(r'Precession Amplitude $\tilde{\theta}$ vs r')
plt.xlabel(r'$r/M$', fontsize = 18)
plt.ylabel(r'$\tilde{\theta}$', fontsize = 18)
plt.xscale('log')
plt.grid()
plt.xlim(6, 1000)

#fig = plt.gcf()
#fig.savefig('figs/validation_theta_tilde_q01_05.pdf', format='pdf', bbox_inches = 'tight')
# Out:
# (6, 1000)

# %%
plt.figure(figsize=(5, 4))
plt.plot(r_array_edit, theta_s1_p5_edit_new, color="green", linestyle = '--')
plt.plot(r_array_edit, theta_s1_p50_edit_new, color="green", linestyle = '-', linewidth=2, label = r'$q = 1$')
plt.plot(r_array_edit, theta_s1_p95_edit_new, color="green", linestyle = '--')

plt.plot(r_arr_new, np.array(p5_theta_tilde_q05_new)*4*eta_05, color = 'blue', linestyle = '--')
plt.plot(r_arr_new, np.array(p50_theta_tilde_q05_new)*4*eta_05, color = 'blue', linestyle = '-', linewidth = 2, label = r'$q = 0.5$')
plt.plot(r_arr_new, np.array(p95_theta_tilde_q05_new)*4*eta_05, color = 'blue', linestyle = '--')

plt.plot(r_arr_new, np.array(p5_theta_tilde_q01_new)*4*eta_01, color = 'orange', linestyle = '--')
plt.plot(r_arr_new, np.array(p50_theta_tilde_q01_new)*4*eta_01, color = 'orange', linestyle = '-', linewidth = 2,label = r'$q = 0.1$')
plt.plot(r_arr_new, np.array(p95_theta_tilde_q01_new)*4*eta_01, color = 'orange', linestyle = '--')

plt.fill_between(r_array_edit, np.array(theta_s1_p5_edit_new).flatten(), np.array(theta_s1_p95_edit_new).flatten(), color="green", alpha=0.4)
plt.fill_between(r_arr_new, np.array(p5_theta_tilde_q05_new)*4*eta_05, np.array(p95_theta_tilde_q05_new)*4*eta_05, color = 'blue', alpha = 0.4)
plt.fill_between(r_arr_new, np.array(p5_theta_tilde_q01_new)*4*eta_01, np.array(p95_theta_tilde_q01_new)*4*eta_01, color = 'orange', alpha = 0.4)

plt.axvline(x = r_at_20_Hz(20, 0.1, 20), color='orange', linestyle=':')#, label=r'r at 20 Hz for $\mathcal{M} = 20 M_{\odot}$ and $q = 0.1$')
plt.axvline(x = r_at_20_Hz(10, 0.1, 20), color='orange', linestyle='-.')#, label=r'r at 20 Hz for $\mathcal{M} = 10 M_{\odot}$ and $q = 0.1$')
plt.axvline(x = r_at_20_Hz(20, 1, 20), color='green', linestyle=':')#, label=r'r at 20 Hz for $\mathcal{M} = 20 M_{\odot}$ and $q = 1$')
plt.axvline(x = r_at_20_Hz(10, 1, 20), color='green', linestyle='-.')#, label=r'r at 20 Hz for $\mathcal{M} = 10 M_{\odot}$ and $q = 1$')
#plt.axvline(x = r_at_20_Hz(40, 1, 20), color='green', linestyle='-')#, label=r'r at 20 Hz for $\mathcal{M} = 40 M_{\odot}$ and $q = 1$')
plt.axvline(x = r_at_20_Hz(20, 0.5, 20), color='blue', linestyle=':')#, label=r'r at 20 Hz for $\mathcal{M} = 20 M_{\odot}$ and $q = 0.5$')
plt.axvline(x = r_at_20_Hz(10, 0.5, 20), color='blue', linestyle='-.')#, label=r'r at 20 Hz for $\mathcal{M} = 10 M_{\odot}$ and $q = 0.5$')

plt.legend(fontsize = 10, loc = 'upper right', framealpha = 0.95)
#plt.title(r'Precession Amplitude $\tilde{\theta}$ vs r')
plt.xlabel(r'$r/M$', fontsize = 18)
plt.ylabel(r'$\tilde{\theta}$', fontsize = 18)
plt.xscale('log')
plt.grid()
plt.xlim(6, 1000)

fig = plt.gcf()
fig.savefig('figs/validation_theta_tilde_q01_05_1_sl_eta_norm.pdf', format='pdf', bbox_inches = 'tight')

# %%
print(4*eta_01, 4*eta_05)
# Out:
# 0.33057851239669417 0.8888888888888888

# %%
plt.figure(figsize=(5, 4))
plt.plot(r_array_edit, omega_s1_p5_edit_new, color="green", linestyle = '--')
plt.plot(r_array_edit, omega_s1_p50_edit_new, color="green", linestyle = '-', linewidth=2)#, label = r'$q = 1$')
plt.plot(r_array_edit, omega_s1_p95_edit_new, color="green", linestyle = '--')

plt.plot(r_arr_new, np.array(p5_omega_tilde_q05_new)/(4*eta_05), color = 'blue', linestyle = '--')
plt.plot(r_arr_new, np.array(p50_omega_tilde_q05_new)/(4*eta_05), color = 'blue', linestyle = '-', linewidth = 2)#, label = r'$q = 0.5$')
plt.plot(r_arr_new, np.array(p95_omega_tilde_q05_new)/(4*eta_05), color = 'blue', linestyle = '--')

plt.plot(r_arr_new, np.array(p5_omega_tilde_q01_new)/(4*eta_01), color = 'orange', linestyle = '--')
plt.plot(r_arr_new, np.array(p50_omega_tilde_q01_new)/(4*eta_01), color = 'orange', linestyle = '-', linewidth = 2)#, label = r'$q = 0.1$')
plt.plot(r_arr_new, np.array(p95_omega_tilde_q01_new)/(4*eta_01), color = 'orange', linestyle = '--')

plt.fill_between(r_array_edit, np.array(omega_s1_p5_edit_new).flatten(), np.array(omega_s1_p95_edit_new).flatten(), color="green", alpha=0.4)
plt.fill_between(r_arr_new, np.array(p5_omega_tilde_q05_new)/(4*eta_05), np.array(p95_omega_tilde_q05_new)/(4*eta_05), color = 'blue', alpha = 0.4)
plt.fill_between(r_arr_new, np.array(p5_omega_tilde_q01_new)/(4*eta_01), np.array(p95_omega_tilde_q01_new)/(4*eta_01), color = 'orange', alpha = 0.4)


plt.axvline(x = r_at_20_Hz(20, 0.1, 20), color='orange', linestyle=':')#, label=r'r at 20 Hz for $\mathcal{M} = 20 M_{\odot}$ and $q = 0.1$')
plt.axvline(x = r_at_20_Hz(10, 0.1, 20), color='orange', linestyle='-.')#, label=r'r at 20 Hz for $\mathcal{M} = 10 M_{\odot}$ and $q = 0.1$')
plt.axvline(x = r_at_20_Hz(20, 1, 20), color='green', linestyle=':', label=r'$r/M$ at $f_{\rm ref}$ for $\mathcal{M}$ = 20 $M_{\odot}$')
plt.axvline(x = r_at_20_Hz(10, 1, 20), color='green', linestyle='-.', label=r'$r/M$ at $f_{\rm ref}$ for $\mathcal{M}$ = 10 $M_{\odot}$')
#plt.axvline(x = r_at_20_Hz(40, 1, 20), color='green', linestyle='-')#, label=r'r at 20 Hz for $\mathcal{M} = 40 M_{\odot}$ and $q = 1$')
plt.axvline(x = r_at_20_Hz(20, 0.5, 20), color='blue', linestyle=':')#, label=r'r at 20 Hz for $\mathcal{M} = 20 M_{\odot}$ and $q = 0.5$')
plt.axvline(x = r_at_20_Hz(10, 0.5, 20), color='blue', linestyle='-.')


plt.legend(fontsize = 10, loc = 'upper right', framealpha = 0.95)
#plt.title(r'Precession Amplitude $\tilde{\theta}$ vs r')
plt.xlabel(r'$r/M$', fontsize = 18)
plt.ylabel(r'$\tilde{\Omega}$', fontsize = 18)
plt.xscale('log')
plt.grid()
plt.ylim(0, 5.5)
plt.xlim(6, 1000)

fig = plt.gcf()
fig.savefig('figs/validation_omega_tilde_q01_05_1_sl_eta_norm.pdf', format='pdf', bbox_inches = 'tight')
