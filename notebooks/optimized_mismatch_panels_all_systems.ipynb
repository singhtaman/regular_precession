# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

with open('saved_data/mismatch_contours_sys/All_mismatches_m10n20.pkl', 'rb') as f:
    data_all_sys_m10n20 = pickle.load(f)

# %% [markdown]
# Already saved mismatches in pickle files

# %%
Z_sys1_m10 = data_all_sys_m10n20['System 1']['mismatch_m10']
Z_sys1_m20 = data_all_sys_m10n20['System 1']['mismatch_m20']

Z_sys2_m10 = data_all_sys_m10n20['System 2']['mismatch_m10']
Z_sys2_m20 = data_all_sys_m10n20['System 2']['mismatch_m20']

Z_sys3_m10 = data_all_sys_m10n20['System 3']['mismatch_m10']
Z_sys3_m20 = data_all_sys_m10n20['System 3']['mismatch_m20']

omega_mesh = data_all_sys_m10n20['System 1']['omega']
theta_mesh = data_all_sys_m10n20['System 1']['theta']

# %%
with open('saved_data/mismatch_contours_sys/Sys_3_mismatches_m20_30_40.pkl', 'rb') as f1:
    data_sys3_m20_30_40 = pickle.load(f1)

# %%
Mismatch_sys3_m20 = data_sys3_m20_30_40['Mismatch m20']
Mismatch_sys3_m30 = data_sys3_m20_30_40['Mismatch m30']
Mismatch_sys3_m40 = data_sys3_m20_30_40['Mismatch m40']

# %%
with open('saved_data/mismatch_contours_sys/Sys_3_mismatches_q05_02_02ext_01_01ext.pkl', 'rb') as f2:
    data_sys3_q05_02_02ext_01_01ext = pickle.load(f2)

# %%
Mismatch_sys3_m10_q05 = data_sys3_q05_02_02ext_01_01ext["Mismatch q05"]
Mismatch_sys3_m10_q02 = data_sys3_q05_02_02ext_01_01ext["Mismatch q02"]
Mismatch_sys3_m10_q02ext = data_sys3_q05_02_02ext_01_01ext["Mismatch q02 extended"]
Mismatch_sys3_m10_q01 = data_sys3_q05_02_02ext_01_01ext["Mismatch q01"]
Mismatch_sys3_m10_q01ext = data_sys3_q05_02_02ext_01_01ext["Mismatch q01 extended"]

# %%
with open('saved_data/mismatch_contours_sys/All_mismatches_for_q1_t_ext.pkl', 'rb') as f:
    extended_mismatch_dict_t_ext = pickle.load(f)

# %%
mismatch_sys1_m10_t_ext = extended_mismatch_dict_t_ext['System 1']['chirp 10']
mismatch_sys2_m10_t_ext = extended_mismatch_dict_t_ext['System 2']['chirp 10']
mismatch_sys3_m10_t_ext = extended_mismatch_dict_t_ext['System 3']['chirp 10']
mismatch_sys3_m20_t_ext = extended_mismatch_dict_t_ext['System 3']['chirp 20']
mismatch_sys3_m30_t_ext = extended_mismatch_dict_t_ext['System 3']['chirp 30']
mismatch_sys3_m40_t_ext = extended_mismatch_dict_t_ext['System 3']['chirp 40']

# %% [markdown]
# Precession param distribution

# %%
    
with open('saved_data/precession_param_dist_s02_q1.pkl', 'rb') as f:
    Values_for_s02 = pickle.load(f)

with open('saved_data/precession_param_dist_s1_q050201.pkl', 'rb') as f:
    Values_for_s1 = pickle.load(f)
    
with open('saved_data/precession_param_dist_s10501_q1.pkl', 'rb') as f:
    Values_for_q1 = pickle.load(f)

# %%
bracket_theta_values_s1_q1 = Values_for_q1['s = 1']['values']['bracket_theta']
bracket_theta_values_s05_q1 = Values_for_q1['s = 0.5']['values']['bracket_theta']
bracket_theta_values_s01_q1 = Values_for_q1['s = 0.1']['values']['bracket_theta']

bracket_theta_values_s1_q05 = Values_for_s1['q = 0.5']['values']['bracket_theta']
bracket_theta_values_s1_q02 = Values_for_s1['q = 0.2']['values']['bracket_theta']
bracket_theta_values_s1_q01 = Values_for_s1['q = 0.1']['values']['bracket_theta']

bracket_omega_values_s1_q1 = Values_for_q1['s = 1']['values']['bracket_omega']
bracket_omega_values_s05_q1 = Values_for_q1['s = 0.5']['values']['bracket_omega']
bracket_omega_values_s01_q1 = Values_for_q1['s = 0.1']['values']['bracket_omega']

bracket_omega_values_s1_q05 = Values_for_s1['q = 0.5']['values']['bracket_omega']
bracket_omega_values_s1_q02 = Values_for_s1['q = 0.2']['values']['bracket_omega']
bracket_omega_values_s1_q01 = Values_for_s1['q = 0.1']['values']['bracket_omega']

bracket_theta_values_s02_q1 = Values_for_s02['all values']['bracket_theta']

bracket_omega_values_s02_q1 = Values_for_s02['all values']['bracket_omega']

# %%
mass2sec = 4.92624076 * 1e-6

data_s1_q1 = np.vstack((np.array(bracket_omega_values_s1_q1).flatten()/(1000*mass2sec), np.array(bracket_theta_values_s1_q1).flatten()*10)).T
data_s05_q1 = np.vstack((np.array(bracket_omega_values_s05_q1).flatten()/(1000*mass2sec), np.array(bracket_theta_values_s05_q1).flatten()*10)).T
data_s01_q1 = np.vstack((np.array(bracket_omega_values_s01_q1).flatten()/(1000*mass2sec), np.array(bracket_theta_values_s01_q1).flatten()*10)).T

data_s1_q05 = np.vstack((np.array(bracket_omega_values_s1_q05).flatten()/(1000*mass2sec), np.array(bracket_theta_values_s1_q05).flatten()*10)).T
data_s1_q02 = np.vstack((np.array(bracket_omega_values_s1_q02).flatten()/(1000*mass2sec), np.array(bracket_theta_values_s1_q02).flatten()*10)).T
data_s1_q01 = np.vstack((np.array(bracket_omega_values_s1_q01).flatten()/(1000*mass2sec), np.array(bracket_theta_values_s1_q01).flatten()*10)).T

data_s02_q1 = np.vstack((np.array(bracket_omega_values_s02_q1).flatten()/(1000*mass2sec), np.array(bracket_theta_values_s02_q1).flatten()*10)).T

# %%
fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(9,7.5), sharey=True, sharex=True)
import matplotlib.tri as mtri

color_levels_row1 = np.linspace(start=0, stop=0.23, num=50)
color_levels_row2 = np.linspace(start=0, stop=0.13, num=50)
color_levels_row3 = np.linspace(start=0, stop=0.28, num=50)  # change this as per your requirement

color_map = 'jet'

X, Y = np.meshgrid(omega_mesh, theta_mesh)

omega_mesh = np.linspace(0, 3, 31)
theta_mesh_q05 = np.linspace(0, 16, 61)
theta_mesh_q02 = np.linspace(0, 24, 91)
theta_mesh_q01 = np.linspace(0, 32, 121)

X_q05, Y_q05 = np.meshgrid(omega_mesh, theta_mesh_q05)
X_q02, Y_q02 = np.meshgrid(omega_mesh, theta_mesh_q02)
X_q01, Y_q01 = np.meshgrid(omega_mesh, theta_mesh_q01)

# plot the data
contour1 = ax[0,0].contourf(X, Y, Z_sys1_m10, cmap=color_map, levels=color_levels_row1)
ax[0,1].contourf(X, Y, Z_sys2_m10, cmap=color_map, levels=color_levels_row1)
ax[0,2].contourf(X, Y, Z_sys3_m10, cmap=color_map, levels=color_levels_row1)


contour2 = ax[1, 0].contourf(X, Y, Z_sys3_m20, cmap=color_map, levels=color_levels_row2)
ax[1, 1].contourf(X, Y, Mismatch_sys3_m30, cmap=color_map, levels=color_levels_row2)
ax[1, 2].contourf(X, Y, Mismatch_sys3_m40, cmap=color_map, levels=color_levels_row2)

contour3 = ax[2, 0].contourf(X_q05, Y_q05, Mismatch_sys3_m10_q05, cmap=color_map, levels=color_levels_row3)
ax[2, 1].contourf(X_q02, Y_q02, Mismatch_sys3_m10_q02ext, cmap=color_map, levels=color_levels_row3)
ax[2, 2].contourf(X_q01, Y_q01, Mismatch_sys3_m10_q01ext, cmap=color_map, levels=color_levels_row3)





# set the limit of x and y axes
ax[0,0].set_xlim(1, 3)
ax[0,0].set_ylim(0, 8)

ax[0,0].text(0.05, 0.10, 'System 1', transform=ax[0,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[0,1].text(0.05, 0.10, 'System 2', transform=ax[0,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[0,2].text(0.05, 0.10, 'System 3', transform=ax[0,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[1,0].text(0.05, 0.10, s=r'$\mathcal{M} = 20 M_{\odot}$', transform=ax[1,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[1,1].text(0.05, 0.10, s=r'$\mathcal{M} = 30 M_{\odot}$', transform=ax[1,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[1,2].text(0.05, 0.10, s=r'$\mathcal{M} = 40 M_{\odot}$', transform=ax[1,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[2,0].text(0.05, 0.10, s=r'$q = 0.5$', transform=ax[2,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[2,1].text(0.05, 0.10, s=r'$q = 0.2$', transform=ax[2,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[2,2].text(0.05, 0.10, s=r'$q = 0.1$', transform=ax[2,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

# add the common x and y labels
fig.text(x=0.4, y=-0.02, s=r'$\tilde{\Omega}$', ha='center', fontweight='bold', fontsize = 18) 
fig.text(x=-0.01, y=0.5, s=r'$\tilde{\theta}$', va='center', fontweight='bold', rotation='vertical', fontsize = 18)

fig.tight_layout()

# adding colorbars
cbar1 = fig.colorbar(contour1, ax=ax[0,:].ravel().tolist(), orientation='vertical')
cbar2 = fig.colorbar(contour2, ax=ax[1,:].ravel().tolist(), orientation='vertical')
cbar3 = fig.colorbar(contour3, ax=ax[2,:].ravel().tolist(), orientation='vertical')

cbar1.set_ticks(np.arange(0, 0.225, 0.05))
cbar2.set_ticks([0, 0.025, 0.05, 0.075, 0.1, 0.125]) 
cbar3.set_ticks([0, 0.05, 0.1, 0.15, 0.2, 0.25])  # change this as per your requirement

# customize the colorbars
#cbar1.ax.set_ylabel(r'$\epsilon_{\rm P}$', fontweight='bold', fontsize = 18)
cbar2.ax.set_ylabel(r'$\epsilon_{\rm p}$', fontweight='bold', fontsize = 18)
#cbar3.ax.set_ylabel(r'$\epsilon_{\rm P}$', fontweight='bold', fontsize = 18)

# Add the legend to the plot
# Out:
# Text(0, 0.5, '$\\epsilon_{\\rm p}$')

# %%
import corner
ranges = [[1, 3], [0, 10]]
figure = corner.hist2d(data_s1_q1[:,0], data_s1_q1[:,1], color='red', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':2})
corner.hist2d(data_s05_q1[:,0], data_s05_q1[:,1], color='blue', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':2})
corner.hist2d(data_s02_q1[:,0], data_s02_q1[:,1], color='green', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9, 0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':[2, 0]})
corner.hist2d(data_s02_q1[:,0], data_s02_q1[:,1], color='green', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9, 0.5), range=ranges, smooth=0.6, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':[0, 2]})

# %%
fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(9,7.5), sharey=False, sharex=True)
import matplotlib.tri as mtri

color_levels_row1 = np.linspace(start=0, stop=0.23, num=50)
color_levels_row2 = np.linspace(start=0, stop=0.13, num=50)
color_levels_row3 = np.linspace(start=0, stop=0.28, num=50)  # change this as per your requirement

color_map = 'jet'

X, Y = np.meshgrid(omega_mesh, theta_mesh)

omega_mesh = np.linspace(0, 3, 31)
theta_mesh_q05 = np.linspace(0, 16, 61)
theta_mesh_q02 = np.linspace(0, 24, 91)
theta_mesh_q01 = np.linspace(0, 32, 121)

X_q05, Y_q05 = np.meshgrid(omega_mesh, theta_mesh_q05)
X_q02, Y_q02 = np.meshgrid(omega_mesh, theta_mesh_q02)
X_q01, Y_q01 = np.meshgrid(omega_mesh, theta_mesh_q01)

# plot the data
contour1 = ax[0,0].contourf(X, Y, Z_sys1_m10, cmap=color_map, levels=color_levels_row1)
ax[0,1].contourf(X, Y, Z_sys2_m10, cmap=color_map, levels=color_levels_row1)
ax[0,2].contourf(X, Y, Z_sys3_m10, cmap=color_map, levels=color_levels_row1)


contour2 = ax[1, 0].contourf(X, Y, Z_sys3_m20, cmap=color_map, levels=color_levels_row2)
ax[1, 1].contourf(X, Y, Mismatch_sys3_m30, cmap=color_map, levels=color_levels_row2)
ax[1, 2].contourf(X, Y, Mismatch_sys3_m40, cmap=color_map, levels=color_levels_row2)

contour3 = ax[2, 0].contourf(X_q05, Y_q05, Mismatch_sys3_m10_q05, cmap=color_map, levels=color_levels_row3)
ax[2, 1].contourf(X_q02, Y_q02, Mismatch_sys3_m10_q02ext, cmap=color_map, levels=color_levels_row3)
ax[2, 2].contourf(X_q01, Y_q01, Mismatch_sys3_m10_q01ext, cmap=color_map, levels=color_levels_row3)


corner.hist2d(data_s1_q1[:,0], data_s1_q1[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':2}, ax=ax[1,0])
corner.hist2d(data_s05_q1[:,0], data_s05_q1[:,1], color='cyan', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':2}, ax=ax[1,0])
corner.hist2d(data_s02_q1[:,0], data_s02_q1[:,1], color='red', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9, 0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':[2, 0]}, ax=ax[1,0])
corner.hist2d(data_s02_q1[:,0], data_s02_q1[:,1], color='red', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9, 0.5), range=ranges, smooth=0.6, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':[0, 2]}, ax=ax[1,0])


corner.hist2d(data_s1_q05[:,0], data_s1_q05[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0.1, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':2}, ax=ax[2,0])
corner.hist2d(data_s1_q02[:,0], data_s1_q02[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0.1, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':2}, ax=ax[2,1])
corner.hist2d(data_s1_q01[:,0], data_s1_q01[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0.1, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':2}, ax=ax[2,2])

# set the limit of x and y axes
ax[0,0].set_xlim(1, 3)
ax[0,0].set_ylim(0, 8)
ax[1,0].set_xlim(1, 3)
ax[1,0].set_ylim(0, 8)

ax[2,0].set_ylim(0, 8)
ax[2,1].set_ylim(0, 8)
ax[2,2].set_ylim(0, 8)


ax[0,0].text(0.05, 0.10, 'System 1', transform=ax[0,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[0,1].text(0.05, 0.10, 'System 2', transform=ax[0,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[0,2].text(0.05, 0.10, 'System 3', transform=ax[0,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[1,0].text(0.05, 0.10, s=r'$\mathcal{M} = 20 M_{\odot}$', transform=ax[1,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[1,1].text(0.05, 0.10, s=r'$\mathcal{M} = 30 M_{\odot}$', transform=ax[1,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[1,2].text(0.05, 0.10, s=r'$\mathcal{M} = 40 M_{\odot}$', transform=ax[1,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[2,0].text(0.05, 0.10, s=r'$q = 0.5$', transform=ax[2,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[2,1].text(0.05, 0.10, s=r'$q = 0.2$', transform=ax[2,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[2,2].text(0.05, 0.10, s=r'$q = 0.1$', transform=ax[2,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

# add the common x and y labels
fig.text(x=0.4, y=-0.02, s=r'$\tilde{\Omega}$', ha='center', fontweight='bold', fontsize = 18) 
fig.text(x=-0.01, y=0.5, s=r'$\tilde{\theta}$', va='center', fontweight='bold', rotation='vertical', fontsize = 18)

fig.tight_layout()

# adding colorbars
cbar1 = fig.colorbar(contour1, ax=ax[0,:].ravel().tolist(), orientation='vertical')
cbar2 = fig.colorbar(contour2, ax=ax[1,:].ravel().tolist(), orientation='vertical')
cbar3 = fig.colorbar(contour3, ax=ax[2,:].ravel().tolist(), orientation='vertical')

cbar1.set_ticks([0, 0.05, 0.1, 0.15, 0.2])
cbar2.set_ticks([0, 0.025, 0.05, 0.075, 0.1, 0.125]) 
cbar3.set_ticks([0, 0.05, 0.1, 0.15, 0.2, 0.25])  # change this as per your requirement

# customize the colorbars
#cbar1.ax.set_ylabel(r'$\epsilon_{\rm P}$', fontweight='bold', fontsize = 14)
cbar2.ax.set_ylabel(r'$\epsilon_{\rm p}$', fontweight='bold', fontsize = 18)
#cbar3.ax.set_ylabel(r'$\epsilon_{\rm P}$', fontweight='bold', fontsize = 14)

# Add the legend to the plot
# Out:
# Text(0, 0.5, '$\\epsilon_{\\rm p}$')

# %%
fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(9,7.5), sharey=False, sharex=True)
import matplotlib.tri as mtri

color_levels_row1 = np.linspace(start=0, stop=0.40, num=50)
color_levels_row2 = np.linspace(start=0, stop=0.2, num=50)
color_levels_row3 = np.linspace(start=0, stop=0.40, num=50)  # change this as per your requirement

color_map = 'jet'


omega_mesh = np.linspace(0, 3, 51)
theta_mesh = np.linspace(0, 10, 51)
theta_mesh_q05 = np.linspace(0, 16, 61)
theta_mesh_q02 = np.linspace(0, 24, 91)
theta_mesh_q01 = np.linspace(0, 32, 121)

omega_mesh_old = np.linspace(0, 3, 31)
X, Y = np.meshgrid(omega_mesh, theta_mesh)

X_q05, Y_q05 = np.meshgrid(omega_mesh_old, theta_mesh_q05)
X_q02, Y_q02 = np.meshgrid(omega_mesh_old, theta_mesh_q02)
X_q01, Y_q01 = np.meshgrid(omega_mesh_old, theta_mesh_q01)

# plot the data
contour1 = ax[0,0].contourf(X, Y, mismatch_sys1_m10_t_ext, cmap=color_map, levels=color_levels_row1)
ax[0,1].contourf(X, Y, mismatch_sys2_m10_t_ext, cmap=color_map, levels=color_levels_row1)
ax[0,2].contourf(X, Y, mismatch_sys3_m10_t_ext, cmap=color_map, levels=color_levels_row1)


contour2 = ax[1, 0].contourf(X, Y, mismatch_sys3_m20_t_ext, cmap=color_map, levels=color_levels_row2)
ax[1, 1].contourf(X, Y, mismatch_sys3_m30_t_ext, cmap=color_map, levels=color_levels_row2)
ax[1, 2].contourf(X, Y, mismatch_sys3_m40_t_ext, cmap=color_map, levels=color_levels_row2)

contour3 = ax[2, 0].contourf(X_q05, Y_q05, Mismatch_sys3_m10_q05, cmap=color_map, levels=color_levels_row3)
ax[2, 1].contourf(X_q02, Y_q02, Mismatch_sys3_m10_q02ext, cmap=color_map, levels=color_levels_row3)
ax[2, 2].contourf(X_q01, Y_q01, Mismatch_sys3_m10_q01ext, cmap=color_map, levels=color_levels_row3)


corner.hist2d(data_s1_q1[:,0], data_s1_q1[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':2}, ax=ax[1,0])
corner.hist2d(data_s05_q1[:,0], data_s05_q1[:,1], color='cyan', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':2}, ax=ax[1,0])
corner.hist2d(data_s02_q1[:,0], data_s02_q1[:,1], color='red', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9, 0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':[2, 0]}, ax=ax[1,0])
corner.hist2d(data_s02_q1[:,0], data_s02_q1[:,1], color='red', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9, 0.5), range=ranges, smooth=0.6, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':[0, 2]}, ax=ax[1,0])

ranges_new = [[0, 3], [0, 32]]

corner.hist2d(data_s1_q05[:,0], data_s1_q05[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0.1, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':2}, ax=ax[2,0])
corner.hist2d(data_s1_q02[:,0], data_s1_q02[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0.1, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':2}, ax=ax[2,1])
corner.hist2d(data_s1_q01[:,0], data_s1_q01[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0.1, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':2}, ax=ax[2,2])

# set the limit of x and y axes
ax[0,0].set_xlim(0, 3)
ax[0,0].set_ylim(0, 10)
ax[1,0].set_ylim(0, 10)

ax[0,1].set_ylim(0, 10)
ax[1,1].set_ylim(0, 10)

ax[0,2].set_ylim(0, 10)
ax[1,2].set_ylim(0, 10)


ax[2,0].set_ylim(0, 12)
ax[2,1].set_ylim(0, 24)
ax[2,2].set_ylim(0, 27)


ax[0,0].text(0.025, 0.10, 'System 1', transform=ax[0,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[0,1].text(0.025, 0.10, 'System 2', transform=ax[0,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[0,2].text(0.025, 0.10, 'System 3', transform=ax[0,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[1,0].text(0.025, 0.10, s=r'$\mathcal{M} = 20 M_{\odot}$', transform=ax[1,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[1,1].text(0.025, 0.10, s=r'$\mathcal{M} = 30 M_{\odot}$', transform=ax[1,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[1,2].text(0.025, 0.10, s=r'$\mathcal{M} = 40 M_{\odot}$', transform=ax[1,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[2,0].text(0.025, 0.10, s=r'$q = 0.5$', transform=ax[2,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[2,1].text(0.025, 0.10, s=r'$q = 0.2$', transform=ax[2,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[2,2].text(0.025, 0.10, s=r'$q = 0.1$', transform=ax[2,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

# add the common x and y labels
fig.text(x=0.4, y=-0.02, s=r'$\tilde{\Omega}$', ha='center', fontweight='bold', fontsize = 18) 
fig.text(x=-0.01, y=0.5, s=r'$\tilde{\theta}$', va='center', fontweight='bold', rotation='vertical', fontsize = 18)

fig.tight_layout()

# adding colorbars
cbar1 = fig.colorbar(contour1, ax=ax[0,:].ravel().tolist(), orientation='vertical')
cbar2 = fig.colorbar(contour2, ax=ax[1,:].ravel().tolist(), orientation='vertical')
cbar3 = fig.colorbar(contour3, ax=ax[2,:].ravel().tolist(), orientation='vertical')

cbar1.set_ticks([0, 0.08, 0.16, 0.24, 0.32, 0.40])
cbar2.set_ticks([0, 0.04, 0.08, 0.12, 0.16, 0.20])
cbar3.set_ticks([0, 0.08, 0.16, 0.24, 0.32, 0.40])  # change this as per your requirement

# customize the colorbars
#cbar1.ax.set_ylabel(r'$\epsilon_{\rm P}$', fontweight='bold', fontsize = 18)
cbar2.ax.set_ylabel(r'$\epsilon_{\rm p}$', fontweight='bold', fontsize = 18)
#cbar3.ax.set_ylabel(r'$\epsilon_{\rm P}$', fontweight='bold', fontsize = 18)
# Out:
# Text(0, 0.5, '$\\epsilon_{\\rm p}$')

# %%
plt.contourf(X_q01, Y_q01, Mismatch_sys3_m10_q01ext, cmap='jet', levels=np.linspace(0, 0.40, 50))
cbar = plt.colorbar(orientation='vertical')
cbar.set_ticks(np.arange(0, 0.45, 0.05))
plt.xlabel(r'$\tilde{\Omega}$', fontsize=14)
plt.ylabel(r'$\tilde{\theta}$', fontsize=14)
plt.title(r'System 3, $\mathcal{M} = 10~M_{\odot}$, $q = 0.1$', fontsize=14)
cbar.set_label(r'$\epsilon_{\rm p}$', fontsize=14)
plt.tight_layout()
plt.show()

# %%
with open("saved_data/mismatch_contours_sys/Sys_3_mismatches_m10_q02_t_ext_lil_more.pkl", "rb") as f:
    Mismatch_sys3_m10_q02ext = pickle.load(f)

# %%
mismatch_sys3_m10_q02_t_ext = Mismatch_sys3_m10_q02ext['mismatch']

# %% [markdown]
# Final figure

# %%
fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(9,7.5), sharey=False, sharex=True)
import matplotlib.tri as mtri

color_levels_row1 = np.linspace(start=0, stop=0.40, num=50)
color_levels_row2 = np.linspace(start=0, stop=0.2, num=50)
color_levels_row3 = np.linspace(start=0, stop=0.40, num=50)  # change this as per your requirement

color_map = 'jet'


omega_mesh = np.linspace(0, 3, 51)
theta_mesh = np.linspace(0, 10, 51)
theta_mesh_q05 = np.linspace(0, 16, 61)
theta_mesh_q02_new = np.linspace(0, 28, 91)
theta_mesh_q01 = np.linspace(0, 32, 121)

omega_mesh_old = np.linspace(0, 3, 31)
X, Y = np.meshgrid(omega_mesh, theta_mesh)

X_q05, Y_q05 = np.meshgrid(omega_mesh_old, theta_mesh_q05)
X_q02_new, Y_q02_new = np.meshgrid(omega_mesh_old, theta_mesh_q02_new)
X_q01, Y_q01 = np.meshgrid(omega_mesh_old, theta_mesh_q01)

# plot the data
contour1 = ax[0,0].contourf(X, Y, mismatch_sys1_m10_t_ext, cmap=color_map, levels=color_levels_row1)
ax[0,1].contourf(X, Y, mismatch_sys2_m10_t_ext, cmap=color_map, levels=color_levels_row1)
ax[0,2].contourf(X, Y, mismatch_sys3_m10_t_ext, cmap=color_map, levels=color_levels_row1)


contour2 = ax[1, 0].contourf(X, Y, mismatch_sys3_m20_t_ext, cmap=color_map, levels=color_levels_row2)
ax[1, 1].contourf(X, Y, mismatch_sys3_m30_t_ext, cmap=color_map, levels=color_levels_row2)
ax[1, 2].contourf(X, Y, mismatch_sys3_m40_t_ext, cmap=color_map, levels=color_levels_row2)

contour3 = ax[2, 0].contourf(X_q05, Y_q05, Mismatch_sys3_m10_q05, cmap=color_map, levels=color_levels_row3)
ax[2, 1].contourf(X_q02_new, Y_q02_new, mismatch_sys3_m10_q02_t_ext, cmap=color_map, levels=color_levels_row3)
ax[2, 2].contourf(X_q01, Y_q01, Mismatch_sys3_m10_q01ext, cmap=color_map, levels=color_levels_row3)



corner.hist2d(data_s1_q1[:,0], data_s1_q1[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,2])
corner.hist2d(data_s05_q1[:,0], data_s05_q1[:,1], color='cyan', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,2])
corner.hist2d(data_s02_q1[:,0], data_s02_q1[:,1], color='red', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9, 0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,2])


corner.hist2d(data_s1_q1[:,0], data_s1_q1[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,1])
corner.hist2d(data_s05_q1[:,0], data_s05_q1[:,1], color='cyan', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,1])
corner.hist2d(data_s02_q1[:,0], data_s02_q1[:,1], color='red', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9, 0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,1])


corner.hist2d(data_s1_q1[:,0], data_s1_q1[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,0])
corner.hist2d(data_s05_q1[:,0], data_s05_q1[:,1], color='cyan', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,0])
corner.hist2d(data_s02_q1[:,0], data_s02_q1[:,1], color='red', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9, 0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,0])


ranges_new = [[0, 3], [0, 32]]

corner.hist2d(data_s1_q05[:,0], data_s1_q05[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[2,0])
corner.hist2d(data_s1_q02[:,0], data_s1_q02[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[2,1])
corner.hist2d(data_s1_q01[:,0], data_s1_q01[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[2,2])

# set the limit of x and y axes
ax[0,0].set_xlim(1, 3)
ax[0,0].set_ylim(0, 10)
ax[1,0].set_ylim(0, 10)

ax[0,1].set_ylim(0, 10)
ax[1,1].set_ylim(0, 10)

ax[0,2].set_ylim(0, 10)
ax[1,2].set_ylim(0, 10)


ax[2,0].set_ylim(0, 14)
ax[2,1].set_ylim(0, 28)
ax[2,2].set_ylim(0, 28)

ax[2,2].set_xticks

ax[0,0].text(0.025, 0.10, 'System 1', transform=ax[0,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[0,1].text(0.025, 0.10, 'System 2', transform=ax[0,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[0,2].text(0.025, 0.10, 'System 3', transform=ax[0,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[1,0].text(0.025, 0.10, s=r'$\mathcal{M} = 20 M_{\odot}$', transform=ax[1,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[1,1].text(0.025, 0.10, s=r'$\mathcal{M} = 30 M_{\odot}$', transform=ax[1,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[1,2].text(0.025, 0.10, s=r'$\mathcal{M} = 40 M_{\odot}$', transform=ax[1,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[2,0].text(0.025, 0.10, s=r'$q = 0.5$', transform=ax[2,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[2,1].text(0.025, 0.10, s=r'$q = 0.2$', transform=ax[2,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[2,2].text(0.025, 0.10, s=r'$q = 0.1$', transform=ax[2,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[2, 0].set_yticks([0, 3.5, 7, 10.5, 14])
ax[2, 1].set_yticks([0, 7, 14, 21, 28])
ax[2, 2].set_yticks([0, 7, 14, 21, 28])

# add the common x and y labels
fig.text(x=0.4, y=-0.02, s=r'$\tilde{\Omega}$', ha='center', fontweight='bold', fontsize = 18) 
fig.text(x=-0.01, y=0.5, s=r'$\tilde{\theta}$', va='center', fontweight='bold', rotation='vertical', fontsize = 18)

fig.tight_layout()

# adding colorbars
cbar1 = fig.colorbar(contour1, ax=ax[0,:].ravel().tolist(), orientation='vertical')
cbar2 = fig.colorbar(contour2, ax=ax[1,:].ravel().tolist(), orientation='vertical')
cbar3 = fig.colorbar(contour3, ax=ax[2,:].ravel().tolist(), orientation='vertical')

cbar1.set_ticks([0, 0.08, 0.16, 0.24, 0.32, 0.40])
cbar2.set_ticks([0, 0.04, 0.08, 0.12, 0.16, 0.20])
cbar3.set_ticks([0, 0.08, 0.16, 0.24, 0.32, 0.40])  # change this as per your requirement

# customize the colorbars
#cbar1.ax.set_ylabel(r'$\epsilon_{\rm P}$', fontweight='bold', fontsize = 18)
cbar2.ax.set_ylabel(r'$\epsilon_{\rm p}$', fontweight='bold', fontsize = 18)
#cbar3.ax.set_ylabel(r'$\epsilon_{\rm P}$', fontweight='bold', fontsize = 18)

# Add the legend to the plot

fig1 = plt.gcf()
fig1.savefig('figs/opt_mismatch_allsys_chirpmass_massratio_with_paramdist_ISO.pdf', bbox_inches='tight', format='pdf')

# %% [markdown]
# Edits to normalize over eta

# %%
fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(9,7.5), sharey=False, sharex=True)
import matplotlib.tri as mtri

eta_01 = 0.1/(1+0.1)**2
eta_02 = 0.2/(1+0.2)**2
eta_05 = 0.5/(1+0.5)**2

color_levels_row1 = np.linspace(start=0, stop=0.40, num=50)
color_levels_row2 = np.linspace(start=0, stop=0.2, num=50)
color_levels_row3 = np.linspace(start=0, stop=0.40, num=50)  # change this as per your requirement

color_map = 'jet'


omega_mesh = np.linspace(0, 3, 51)
theta_mesh = np.linspace(0, 10, 51)
theta_mesh_q05 = np.linspace(0, 16, 61)
theta_mesh_q02_new = np.linspace(0, 28, 91)
theta_mesh_q01 = np.linspace(0, 32, 121)

omega_mesh_old = np.linspace(0, 3, 31)
X, Y = np.meshgrid(omega_mesh, theta_mesh)

X_q05, Y_q05 = np.meshgrid(omega_mesh_old, theta_mesh_q05)
X_q02_new, Y_q02_new = np.meshgrid(omega_mesh_old, theta_mesh_q02_new)
X_q01, Y_q01 = np.meshgrid(omega_mesh_old, theta_mesh_q01)

# plot the data
contour1 = ax[0,0].contourf(X, Y, mismatch_sys1_m10_t_ext, cmap=color_map, levels=color_levels_row1)
ax[0,1].contourf(X, Y, mismatch_sys2_m10_t_ext, cmap=color_map, levels=color_levels_row1)
ax[0,2].contourf(X, Y, mismatch_sys3_m10_t_ext, cmap=color_map, levels=color_levels_row1)


contour2 = ax[1, 0].contourf(X, Y, mismatch_sys3_m20_t_ext, cmap=color_map, levels=color_levels_row2)
ax[1, 1].contourf(X, Y, mismatch_sys3_m30_t_ext, cmap=color_map, levels=color_levels_row2)
ax[1, 2].contourf(X, Y, mismatch_sys3_m40_t_ext, cmap=color_map, levels=color_levels_row2)

contour3 = ax[2, 0].contourf(X_q05, Y_q05, Mismatch_sys3_m10_q05, cmap=color_map, levels=color_levels_row3)
ax[2, 1].contourf(X_q02_new, Y_q02_new, mismatch_sys3_m10_q02_t_ext, cmap=color_map, levels=color_levels_row3)
ax[2, 2].contourf(X_q01, Y_q01, Mismatch_sys3_m10_q01ext, cmap=color_map, levels=color_levels_row3)



corner.hist2d(data_s1_q1[:,0], data_s1_q1[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,2])
corner.hist2d(data_s05_q1[:,0], data_s05_q1[:,1], color='cyan', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,2])
corner.hist2d(data_s02_q1[:,0], data_s02_q1[:,1], color='red', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9, 0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,2])


corner.hist2d(data_s1_q1[:,0], data_s1_q1[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,1])
corner.hist2d(data_s05_q1[:,0], data_s05_q1[:,1], color='cyan', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,1])
corner.hist2d(data_s02_q1[:,0], data_s02_q1[:,1], color='red', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9, 0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,1])


corner.hist2d(data_s1_q1[:,0], data_s1_q1[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,0])
corner.hist2d(data_s05_q1[:,0], data_s05_q1[:,1], color='cyan', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,0])
corner.hist2d(data_s02_q1[:,0], data_s02_q1[:,1], color='red', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9, 0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,0])


ranges_new = [[0, 3], [0, 32]]

corner.hist2d(data_s1_q05[:,0], data_s1_q05[:,1]*(4*eta_05), color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[2,0])
corner.hist2d(data_s1_q02[:,0], data_s1_q02[:,1]*(4*eta_02), color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[2,1])
corner.hist2d(data_s1_q01[:,0], data_s1_q01[:,1]*(4*eta_01), color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[2,2])

# set the limit of x and y axes
ax[0,0].set_xlim(1, 3)
ax[0,0].set_ylim(0, 10)
ax[1,0].set_ylim(0, 10)

ax[0,1].set_ylim(0, 10)
ax[1,1].set_ylim(0, 10)

ax[0,2].set_ylim(0, 10)
ax[1,2].set_ylim(0, 10)


ax[2,0].set_ylim(0, 14)
ax[2,1].set_ylim(0, 28)
ax[2,2].set_ylim(0, 28)

ax[2,2].set_xticks

ax[0,0].text(0.025, 0.10, 'System 1', transform=ax[0,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[0,1].text(0.025, 0.10, 'System 2', transform=ax[0,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[0,2].text(0.025, 0.10, 'System 3', transform=ax[0,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[1,0].text(0.025, 0.10, s=r'$\mathcal{M} = 20 M_{\odot}$', transform=ax[1,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[1,1].text(0.025, 0.10, s=r'$\mathcal{M} = 30 M_{\odot}$', transform=ax[1,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[1,2].text(0.025, 0.10, s=r'$\mathcal{M} = 40 M_{\odot}$', transform=ax[1,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[2,0].text(0.025, 0.10, s=r'$q = 0.5$', transform=ax[2,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[2,1].text(0.025, 0.10, s=r'$q = 0.2$', transform=ax[2,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[2,2].text(0.025, 0.10, s=r'$q = 0.1$', transform=ax[2,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[2, 0].set_yticks([0, 3.5, 7, 10.5, 14])
ax[2, 1].set_yticks([0, 7, 14, 21, 28])
ax[2, 2].set_yticks([0, 7, 14, 21, 28])

# add the common x and y labels
fig.text(x=0.4, y=-0.02, s=r'$\tilde{\Omega}$', ha='center', fontweight='bold', fontsize = 14) 
fig.text(x=-0.01, y=0.5, s=r'$\tilde{\theta}$', va='center', fontweight='bold', rotation='vertical', fontsize = 14)

fig.tight_layout()

# adding colorbars
cbar1 = fig.colorbar(contour1, ax=ax[0,:].ravel().tolist(), orientation='vertical')
cbar2 = fig.colorbar(contour2, ax=ax[1,:].ravel().tolist(), orientation='vertical')
cbar3 = fig.colorbar(contour3, ax=ax[2,:].ravel().tolist(), orientation='vertical')

cbar1.set_ticks([0, 0.08, 0.16, 0.24, 0.32, 0.40])
cbar2.set_ticks([0, 0.04, 0.08, 0.12, 0.16, 0.20])
cbar3.set_ticks([0, 0.08, 0.16, 0.24, 0.32, 0.40])  # change this as per your requirement

# customize the colorbars
#cbar1.ax.set_ylabel(r'$\epsilon_{\rm P}$', fontweight='bold', fontsize = 14)
cbar2.ax.set_ylabel(r'$\epsilon_{\rm p}$', fontweight='bold', fontsize = 14)
#cbar3.ax.set_ylabel(r'$\epsilon_{\rm P}$', fontweight='bold', fontsize = 14)
# Out:
# Text(0, 0.5, '$\\epsilon_{\\rm p}$')

# %%
ranges_new = [[0, 6], [0, 32]]
corner.hist2d(data_s1_q05[:,0], data_s1_q05[:,1], color='k', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5})
corner.hist2d(data_s1_q02[:,0], data_s1_q02[:,1], color='r', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5})
corner.hist2d(data_s1_q01[:,0], data_s1_q01[:,1], color='blue', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5})
plt.xlabel(r"$\tilde{\Omega}$", fontsize=14)
plt.ylabel(r"$\tilde{\theta}$", fontsize=14)
# Out:
# Text(0, 0.5, '$\\tilde{\\theta}$')

# %%
ranges_new = [[0, 3], [0, 15]]
corner.hist2d(data_s1_q05[:,0], data_s1_q05[:,1]*(4*eta_05), color='k', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5})
corner.hist2d(data_s1_q02[:,0], data_s1_q02[:,1]*(4*eta_02), color='r', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5})
corner.hist2d(data_s1_q01[:,0], data_s1_q01[:,1]*(4*eta_01), color='blue', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5})
plt.xlabel(r'$\tilde{\Omega}$', fontsize=14)
plt.ylabel(r'$\tilde{\theta}$', fontsize=14)
plt.ylim(0, 14)
# Out:
# (0.0, 14.0)

# %%
fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(9,7.5), sharey=False, sharex=True)
import matplotlib.tri as mtri

color_levels_row1 = np.linspace(start=0, stop=0.40, num=50)
color_levels_row2 = np.linspace(start=0, stop=0.2, num=50)
color_levels_row3 = np.linspace(start=0, stop=0.40, num=50)  # change this as per your requirement

color_map = 'jet'


omega_mesh = np.linspace(0, 3, 51)
theta_mesh = np.linspace(0, 10, 51)
theta_mesh_q05 = np.linspace(0, 16, 61)
theta_mesh_q02_new = np.linspace(0, 28, 91)
theta_mesh_q01 = np.linspace(0, 32, 121)

omega_mesh_old = np.linspace(0, 3, 31)
X, Y = np.meshgrid(omega_mesh, theta_mesh)

X_q05, Y_q05 = np.meshgrid(omega_mesh_old, theta_mesh_q05)
X_q02_new, Y_q02_new = np.meshgrid(omega_mesh_old, theta_mesh_q02_new)
X_q01, Y_q01 = np.meshgrid(omega_mesh_old, theta_mesh_q01)

# plot the data
contour1 = ax[0,0].contourf(X, Y, mismatch_sys1_m10_t_ext, cmap=color_map, levels=color_levels_row1)
ax[0,1].contourf(X, Y, mismatch_sys2_m10_t_ext, cmap=color_map, levels=color_levels_row1)
ax[0,2].contourf(X, Y, mismatch_sys3_m10_t_ext, cmap=color_map, levels=color_levels_row1)


contour2 = ax[1, 0].contourf(X, Y, mismatch_sys3_m20_t_ext, cmap=color_map, levels=color_levels_row2)
ax[1, 1].contourf(X, Y, mismatch_sys3_m30_t_ext, cmap=color_map, levels=color_levels_row2)
ax[1, 2].contourf(X, Y, mismatch_sys3_m40_t_ext, cmap=color_map, levels=color_levels_row2)

contour3 = ax[2, 0].contourf(X_q05, Y_q05*(4*eta_05), Mismatch_sys3_m10_q05, cmap=color_map, levels=color_levels_row3)
ax[2, 1].contourf(X_q02_new, Y_q02_new*(4*eta_02), mismatch_sys3_m10_q02_t_ext, cmap=color_map, levels=color_levels_row3)
ax[2, 2].contourf(X_q01, Y_q01*(4*eta_01), Mismatch_sys3_m10_q01ext, cmap=color_map, levels=color_levels_row3)



corner.hist2d(data_s1_q1[:,0], data_s1_q1[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,2])
corner.hist2d(data_s05_q1[:,0], data_s05_q1[:,1], color='cyan', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,2])
corner.hist2d(data_s02_q1[:,0], data_s02_q1[:,1], color='red', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9, 0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,2])


corner.hist2d(data_s1_q1[:,0], data_s1_q1[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,1])
corner.hist2d(data_s05_q1[:,0], data_s05_q1[:,1], color='cyan', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,1])
corner.hist2d(data_s02_q1[:,0], data_s02_q1[:,1], color='red', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9, 0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,1])


corner.hist2d(data_s1_q1[:,0], data_s1_q1[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,0])
corner.hist2d(data_s05_q1[:,0], data_s05_q1[:,1], color='cyan', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,0])
corner.hist2d(data_s02_q1[:,0], data_s02_q1[:,1], color='red', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9, 0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,0])


ranges_new = [[0, 3], [0, 15]]

corner.hist2d(data_s1_q05[:,0], data_s1_q05[:,1]*(4*eta_05), color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[2,0])
corner.hist2d(data_s1_q02[:,0], data_s1_q02[:,1]*(4*eta_02), color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[2,1])
corner.hist2d(data_s1_q01[:,0], data_s1_q01[:,1]*(4*eta_01), color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[2,2])

# set the limit of x and y axes
ax[0,0].set_xlim(1, 3)
ax[0,0].set_ylim(0, 10)
ax[1,0].set_ylim(0, 10)

ax[0,1].set_xlim(1, 3)
ax[0,1].set_ylim(0, 10)
ax[1,1].set_ylim(0, 10)

ax[0,2].set_xlim(1, 3)
ax[0,2].set_ylim(0, 10)
ax[1,2].set_ylim(0, 10)

ax[2,0].set_ylim(0, 13.25)
ax[2,1].set_ylim(0, 13.25)
ax[2,2].set_ylim(0, 10)

ax[2,2].set_xticks

ax[0,0].text(0.0275, 0.10, 'System 1', transform=ax[0,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[0,1].text(0.0275, 0.10, 'System 2', transform=ax[0,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[0,2].text(0.0275, 0.10, 'System 3', transform=ax[0,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[1,0].text(0.0275, 0.10, s=r'$\mathcal{M} = 20 M_{\odot}$', transform=ax[1,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[1,1].text(0.0275, 0.10, s=r'$\mathcal{M} = 30 M_{\odot}$', transform=ax[1,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[1,2].text(0.0275, 0.10, s=r'$\mathcal{M} = 40 M_{\odot}$', transform=ax[1,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[2,0].text(0.0275, 0.105, s=r'$q = 0.5$', transform=ax[2,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[2,1].text(0.0275, 0.105, s=r'$q = 0.2$', transform=ax[2,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[2,2].text(0.0275, 0.105, s=r'$q = 0.1$', transform=ax[2,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[2, 0].set_yticks([0, 2.5, 5, 7.5, 10, 12.5])
ax[2, 1].set_yticks([0, 2.5, 5, 7.5, 10, 12.5])
ax[2, 2].set_yticks([0, 2, 4, 6, 8, 10])


ax[2, 0].axhline(y=7.92, color='k', linestyle=':', linewidth=1.5)
ax[2, 0].axhline(y=12.96, color='k', linestyle=':', linewidth=1.5)

ax[2, 1].axhline(y=4.95, color='k', linestyle=':', linewidth=1.5)
ax[2, 1].axhline(y=8.10, color='k', linestyle=':', linewidth=1.5)
#ax[2, 1].scatter(x=2.95, y=14.15, color='k', marker='*', linewidth=1.5)

ax[2, 2].axhline(y=2.95, color='k', linestyle=':', linewidth=1.5)
ax[2, 2].axhline(y=4.82, color='k', linestyle=':', linewidth=1.5)
ax[2, 2].axhline(y=8.42, color='k', linestyle=':', linewidth=1.5)
ax[2, 2].axhline(y=10.25, color='k', linestyle=':', linewidth=1.5)

# add the common x and y labels
fig.text(x=0.4, y=-0.02, s=r'$\tilde{\Omega}$', ha='center', fontweight='bold', fontsize = 18) 
fig.text(x=0.005, y=0.5, s=r'$\tilde{\theta}$', va='center', fontweight='bold', rotation='vertical', fontsize = 18)

fig.tight_layout()

# adding colorbars
cbar1 = fig.colorbar(contour1, ax=ax[0,:].ravel().tolist(), orientation='vertical')
cbar2 = fig.colorbar(contour2, ax=ax[1,:].ravel().tolist(), orientation='vertical')
cbar3 = fig.colorbar(contour3, ax=ax[2,:].ravel().tolist(), orientation='vertical')

cbar1.set_ticks([0, 0.08, 0.16, 0.24, 0.32, 0.40])
cbar2.set_ticks([0, 0.04, 0.08, 0.12, 0.16, 0.20])
cbar3.set_ticks([0, 0.08, 0.16, 0.24, 0.32, 0.40])  # change this as per your requirement

# customize the colorbars
#cbar1.ax.set_ylabel(r'$\epsilon_{\rm P}$', fontweight='bold', fontsize = 18)
cbar2.ax.set_ylabel(r'$\epsilon_{\rm p}$', fontweight='bold', fontsize = 18)
#cbar3.ax.set_ylabel(r'$\epsilon_{\rm P}$', fontweight='bold', fontsize = 18)

# Add the legend to the plot

fig1 = plt.gcf()
fig1.savefig('figs/opt_mismatch_allsys_chirpmass_massratio_with_paramdist_ISO_eta_norm.pdf', bbox_inches='tight', format='pdf')

# %%
fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(9,7.5), sharey=False, sharex=True)
import matplotlib.tri as mtri

color_levels_row1 = np.linspace(start=0, stop=0.40, num=50)
color_levels_row2 = np.linspace(start=0, stop=0.2, num=50)
color_levels_row3 = np.linspace(start=0, stop=0.40, num=50)  # change this as per your requirement

color_map = 'jet'


omega_mesh = np.linspace(0, 3, 51)
theta_mesh = np.linspace(0, 10, 51)
theta_mesh_q05 = np.linspace(0, 16, 61)
theta_mesh_q02_new = np.linspace(0, 28, 91)
theta_mesh_q01 = np.linspace(0, 32, 121)

omega_mesh_old = np.linspace(0, 3, 31)
X, Y = np.meshgrid(omega_mesh, theta_mesh)

X_q05, Y_q05 = np.meshgrid(omega_mesh_old, theta_mesh_q05)
X_q02_new, Y_q02_new = np.meshgrid(omega_mesh_old, theta_mesh_q02_new)
X_q01, Y_q01 = np.meshgrid(omega_mesh_old, theta_mesh_q01)

# plot the data
contour1 = ax[0,0].contourf(X, Y, mismatch_sys1_m10_t_ext, cmap=color_map, levels=color_levels_row1)
ax[0,1].contourf(X, Y, mismatch_sys2_m10_t_ext, cmap=color_map, levels=color_levels_row1)
ax[0,2].contourf(X, Y, mismatch_sys3_m10_t_ext, cmap=color_map, levels=color_levels_row1)


contour2 = ax[1, 0].contourf(X, Y, mismatch_sys3_m20_t_ext, cmap=color_map, levels=color_levels_row2)
ax[1, 1].contourf(X, Y, mismatch_sys3_m30_t_ext, cmap=color_map, levels=color_levels_row2)
ax[1, 2].contourf(X, Y, mismatch_sys3_m40_t_ext, cmap=color_map, levels=color_levels_row2)

contour3 = ax[2, 0].contourf(X_q05, Y_q05*(4*eta_05), Mismatch_sys3_m10_q05, cmap=color_map, levels=color_levels_row3)
ax[2, 1].contourf(X_q02_new, Y_q02_new*(4*eta_02), mismatch_sys3_m10_q02_t_ext, cmap=color_map, levels=color_levels_row3)
ax[2, 2].contourf(X_q01, Y_q01*(4*eta_01), Mismatch_sys3_m10_q01ext, cmap=color_map, levels=color_levels_row3)



corner.hist2d(data_s1_q1[:,0], data_s1_q1[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,2])
corner.hist2d(data_s05_q1[:,0], data_s05_q1[:,1], color='cyan', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,2])
corner.hist2d(data_s02_q1[:,0], data_s02_q1[:,1], color='red', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9, 0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,2])


corner.hist2d(data_s1_q1[:,0], data_s1_q1[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,1])
corner.hist2d(data_s05_q1[:,0], data_s05_q1[:,1], color='cyan', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,1])
corner.hist2d(data_s02_q1[:,0], data_s02_q1[:,1], color='red', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9, 0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,1])


corner.hist2d(data_s1_q1[:,0], data_s1_q1[:,1], color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,0])
corner.hist2d(data_s05_q1[:,0], data_s05_q1[:,1], color='cyan', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,0])
corner.hist2d(data_s02_q1[:,0], data_s02_q1[:,1], color='red', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9, 0.5), range=ranges, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,0])


ranges_new = [[0, 3], [0, 15]]

corner.hist2d(data_s1_q05[:,0], data_s1_q05[:,1]*(4*eta_05), color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[2,0])
corner.hist2d(data_s1_q02[:,0], data_s1_q02[:,1]*(4*eta_02), color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[2,1])
corner.hist2d(data_s1_q01[:,0], data_s1_q01[:,1]*(4*eta_01), color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[2,2])

# set the limit of x and y axes
ax[0,0].set_xlim(1, 3)
ax[0,0].set_ylim(0, 10)
ax[1,0].set_ylim(0, 10)

ax[0,1].set_xlim(1, 3)
ax[0,1].set_ylim(0, 10)
ax[1,1].set_ylim(0, 10)

ax[0,2].set_xlim(1, 3)
ax[0,2].set_ylim(0, 10)
ax[1,2].set_ylim(0, 10)

ax[2,0].set_ylim(0, 13.25)
ax[2,1].set_ylim(0, 13.25)
ax[2,2].set_ylim(0, 10)

ax[2,2].set_xticks

ax[0,0].text(0.0275, 0.10, 'System 1', transform=ax[0,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[0,1].text(0.0275, 0.10, 'System 2', transform=ax[0,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[0,2].text(0.0275, 0.10, 'System 3', transform=ax[0,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[1,0].text(0.0275, 0.10, s=r'$\mathcal{M} = 20 M_{\odot}$', transform=ax[1,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[1,1].text(0.0275, 0.10, s=r'$\mathcal{M} = 30 M_{\odot}$', transform=ax[1,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[1,2].text(0.0275, 0.10, s=r'$\mathcal{M} = 40 M_{\odot}$', transform=ax[1,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[2,0].text(0.0275, 0.105, s=r'$q = 0.5$', transform=ax[2,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[2,1].text(0.0275, 0.105, s=r'$q = 0.2$', transform=ax[2,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[2,2].text(0.0275, 0.105, s=r'$q = 0.1$', transform=ax[2,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[2, 0].set_yticks([0, 2.5, 5, 7.5, 10, 12.5])
ax[2, 1].set_yticks([0, 2.5, 5, 7.5, 10, 12.5])
ax[2, 2].set_yticks([0, 2, 4, 6, 8, 10])

# add the common x and y labels
fig.text(x=0.4, y=-0.02, s=r'$\tilde{\Omega}$', ha='center', fontweight='bold', fontsize = 18) 
fig.text(x=0.005, y=0.5, s=r'$\tilde{\theta}$', va='center', fontweight='bold', rotation='vertical', fontsize = 18)

fig.tight_layout()

# adding colorbars
cbar1 = fig.colorbar(contour1, ax=ax[0,:].ravel().tolist(), orientation='vertical')
cbar2 = fig.colorbar(contour2, ax=ax[1,:].ravel().tolist(), orientation='vertical')
cbar3 = fig.colorbar(contour3, ax=ax[2,:].ravel().tolist(), orientation='vertical')

cbar1.set_ticks([0, 0.08, 0.16, 0.24, 0.32, 0.40])
cbar2.set_ticks([0, 0.04, 0.08, 0.12, 0.16, 0.20])
cbar3.set_ticks([0, 0.08, 0.16, 0.24, 0.32, 0.40])  # change this as per your requirement

# customize the colorbars
#cbar1.ax.set_ylabel(r'$\epsilon_{\rm P}$', fontweight='bold', fontsize = 18)
cbar2.ax.set_ylabel(r'$\epsilon_{\rm p}$', fontweight='bold', fontsize = 18)
#cbar3.ax.set_ylabel(r'$\epsilon_{\rm P}$', fontweight='bold', fontsize = 18)


#theta_tilde_05_values: ['6.22', '10.18', '17.78', '21.64', '9.33', '18.58']
#theta_tilde_02_values: ['3.89', '6.36', '11.11', '13.53', '5.83', '11.61']
#theta_tilde_01_values: ['2.31', '3.79', '6.61', '8.05', '3.47', '6.91']
#theta_tilde_min_05_values: ['12.10', '19.80', '34.58', '42.10', '18.16', '36.14']
#theta_tilde_min_02_values: ['7.56', '12.37', '21.61', '26.31', '11.35', '22.59']
#theta_tilde_min_01_values: ['4.50', '7.36', '12.86', '15.66', '6.75', '13.44']


theta_05_legends = [6.22, 10.18, 9.33]

ax[2, 0].axhline(y=6.22, color='k', linestyle='--', linewidth=1.5)
ax[2, 0].axhline(y=10.18, color='k', linestyle='--', linewidth=1.5)
ax[2, 0].axhline(y=12.10, color='k', linestyle='-.', linewidth=1.5)
#ax[2, 0].axhline(y=9.33, color='magenta', linestyle='--', linewidth=1.5)

theta_02_legends = [3.89, 6.36, 11.11, 13.53, 5.83, 11.61]

ax[2, 1].axhline(y=3.89, color='k', linestyle='--', linewidth=1.5)
ax[2, 1].axhline(y=6.36, color='k', linestyle='--', linewidth=1.5)
ax[2, 1].axhline(y=11.11, color='k', linestyle='--', linewidth=1.5)
ax[2, 1].axhline(y=7.56, color='k', linestyle='-.', linewidth=1.5)
ax[2, 1].axhline(y=12.37, color='k', linestyle='-.', linewidth=1.5)
#ax[2, 1].axhline(y=5.83, color='magenta', linestyle='--', linewidth=1.5)
#ax[2, 1].axhline(y=11.61, color='magenta', linestyle='--', linewidth=1.5)

theta_01_legends = [2.31, 3.79, 6.61, 8.05, 3.47, 6.91]

ax[2, 2].axhline(y=2.31, color='k', linestyle='--', linewidth=1.5)
ax[2, 2].axhline(y=3.79, color='k', linestyle='--', linewidth=1.5)
ax[2, 2].axhline(y=6.61, color='k', linestyle='--', linewidth=1.5)
ax[2, 2].axhline(y=8.05, color='k', linestyle='--', linewidth=1.5)
ax[2, 2].axhline(y=4.50, color='k', linestyle='-.', linewidth=1.5)
ax[2, 2].axhline(y=7.36, color='k', linestyle='-.', linewidth=1.5)
ax[2, 2].axhline(y=12.86, color='k', linestyle='-.', linewidth=1.5)
#ax[2, 2].axhline(y=3.47, color='magenta', linestyle='--', linewidth=1.5)
#ax[2, 2].axhline(y=6.91, color='magenta', linestyle='--', linewidth=1.5)

# %%
fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(9,7.5), sharey=False, sharex=True)
import matplotlib.tri as mtri

color_levels_row3 = np.linspace(start=0, stop=0.40, num=50)  # change this as per your requirement

color_map = 'jet'


omega_mesh = np.linspace(0, 3, 51)
theta_mesh = np.linspace(0, 10, 51)
theta_mesh_q05 = np.linspace(0, 16, 61)
theta_mesh_q02_new = np.linspace(0, 28, 91)
theta_mesh_q01 = np.linspace(0, 32, 121)

omega_mesh_old = np.linspace(0, 3, 31)
X, Y = np.meshgrid(omega_mesh, theta_mesh)

X_q05, Y_q05 = np.meshgrid(omega_mesh_old, theta_mesh_q05)
X_q02_new, Y_q02_new = np.meshgrid(omega_mesh_old, theta_mesh_q02_new)
X_q01, Y_q01 = np.meshgrid(omega_mesh_old, theta_mesh_q01)

# plot the data
contour1 = ax[0, 0].contourf(X_q05, Y_q05*(4*eta_05), Mismatch_sys3_m10_q05, cmap=color_map, levels=color_levels_row3)
ax[0, 1].contourf(X_q02_new, Y_q02_new*(4*eta_02), mismatch_sys3_m10_q02_t_ext, cmap=color_map, levels=color_levels_row3)
ax[0, 2].contourf(X_q01, Y_q01*(4*eta_01), Mismatch_sys3_m10_q01ext, cmap=color_map, levels=color_levels_row3)


contour2 = ax[1, 0].contourf(X_q05, Y_q05*(4*eta_05), Mismatch_sys3_m10_q05, cmap=color_map, levels=color_levels_row3)
ax[1, 1].contourf(X_q02_new, Y_q02_new*(4*eta_02), mismatch_sys3_m10_q02_t_ext, cmap=color_map, levels=color_levels_row3)
ax[1, 2].contourf(X_q01, Y_q01*(4*eta_01), Mismatch_sys3_m10_q01ext, cmap=color_map, levels=color_levels_row3)

contour3 = ax[2, 0].contourf(X_q05, Y_q05*(4*eta_05), Mismatch_sys3_m10_q05, cmap=color_map, levels=color_levels_row3)
ax[2, 1].contourf(X_q02_new, Y_q02_new*(4*eta_02), mismatch_sys3_m10_q02_t_ext, cmap=color_map, levels=color_levels_row3)
ax[2, 2].contourf(X_q01, Y_q01*(4*eta_01), Mismatch_sys3_m10_q01ext, cmap=color_map, levels=color_levels_row3)


ranges_new = [[0, 3], [0, 15]]

corner.hist2d(data_s1_q05[:,0], data_s1_q05[:,1]*(4*eta_05), color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[0,0])
corner.hist2d(data_s1_q02[:,0], data_s1_q02[:,1]*(4*eta_02), color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[0,1])
corner.hist2d(data_s1_q01[:,0], data_s1_q01[:,1]*(4*eta_01), color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[0,2])

corner.hist2d(data_s1_q05[:,0], data_s1_q05[:,1]*(4*eta_05), color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,0])
corner.hist2d(data_s1_q02[:,0], data_s1_q02[:,1]*(4*eta_02), color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,1])
corner.hist2d(data_s1_q01[:,0], data_s1_q01[:,1]*(4*eta_01), color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[1,2])


corner.hist2d(data_s1_q05[:,0], data_s1_q05[:,1]*(4*eta_05), color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[2,0])
corner.hist2d(data_s1_q02[:,0], data_s1_q02[:,1]*(4*eta_02), color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[2,1])
corner.hist2d(data_s1_q01[:,0], data_s1_q01[:,1]*(4*eta_01), color='white', labels=[r"$\tilde{\Omega}$", r"$\tilde{\theta}$"], fontsize = 14, levels=(0.9,0.5), range=ranges_new, smooth=0, no_fill_contours=True, plot_density=False, plot_datapoints=False, plot_contours=True, fill_contours=False, contour_kwargs={'linestyles':['--', '-'], 'linewidths':1.5}, ax=ax[2,2])

# set the limit of x and y axes
ax[0,2].set_xlim(1, 3)
ax[0,0].set_ylim(0, 13.25)
ax[0,1].set_ylim(0, 13.25)
ax[0,2].set_ylim(0, 10)

ax[1,2].set_xlim(1, 3)
ax[1,0].set_ylim(0, 13.25)
ax[1,1].set_ylim(0, 13.25)
ax[1,2].set_ylim(0, 10)

ax[2,2].set_xlim(1, 3)
ax[2,0].set_ylim(0, 13.25)
ax[2,1].set_ylim(0, 13.25)
ax[2,2].set_ylim(0, 10)

ax[2,2].set_xticks

ax[0,0].text(0.0275, 0.105, s=r'$q = 0.5$', transform=ax[2,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[0,1].text(0.0275, 0.105, s=r'$q = 0.2$', transform=ax[2,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[0,2].text(0.0275, 0.105, s=r'$q = 0.1$', transform=ax[2,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[1,0].text(0.0275, 0.105, s=r'$q = 0.5$', transform=ax[2,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[1,1].text(0.0275, 0.105, s=r'$q = 0.2$', transform=ax[2,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[1,2].text(0.0275, 0.105, s=r'$q = 0.1$', transform=ax[2,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[2,0].text(0.0275, 0.105, s=r'$q = 0.5$', transform=ax[2,0].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[2,1].text(0.0275, 0.105, s=r'$q = 0.2$', transform=ax[2,1].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))
ax[2,2].text(0.0275, 0.105, s=r'$q = 0.1$', transform=ax[2,2].transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.75))

ax[0, 0].set_yticks([0, 2.5, 5, 7.5, 10, 12.5])
ax[0, 1].set_yticks([0, 2.5, 5, 7.5, 10, 12.5])
ax[0, 2].set_yticks([0, 2, 4, 6, 8, 10])

ax[1, 0].set_yticks([0, 2.5, 5, 7.5, 10, 12.5])
ax[1, 1].set_yticks([0, 2.5, 5, 7.5, 10, 12.5])
ax[1, 2].set_yticks([0, 2, 4, 6, 8, 10])

ax[2, 0].set_yticks([0, 2.5, 5, 7.5, 10, 12.5])
ax[2, 1].set_yticks([0, 2.5, 5, 7.5, 10, 12.5])
ax[2, 2].set_yticks([0, 2, 4, 6, 8, 10])

# add the common x and y labels
fig.text(x=0.4, y=-0.02, s=r'$\tilde{\Omega}$', ha='center', fontweight='bold', fontsize = 18) 
fig.text(x=0.005, y=0.5, s=r'$\tilde{\theta}$', va='center', fontweight='bold', rotation='vertical', fontsize = 18)

fig.tight_layout(pad=1.0, h_pad=1.0, w_pad=1.0)

# adding colorbars
cbar1 = fig.colorbar(contour1, ax=ax[0,:].ravel().tolist(), orientation='vertical')
cbar2 = fig.colorbar(contour2, ax=ax[1,:].ravel().tolist(), orientation='vertical')
cbar3 = fig.colorbar(contour3, ax=ax[2,:].ravel().tolist(), orientation='vertical')

cbar1.set_ticks([0, 0.08, 0.16, 0.24, 0.32, 0.40]) 
cbar2.set_ticks([0, 0.08, 0.16, 0.24, 0.32, 0.40]) 
cbar3.set_ticks([0, 0.08, 0.16, 0.24, 0.32, 0.40])  # change this as per your requirement

# customize the colorbars
#cbar1.ax.set_ylabel(r'$\epsilon_{\rm P}$', fontweight='bold', fontsize = 18)
cbar2.ax.set_ylabel(r'$\epsilon_{\rm p}$', fontweight='bold', fontsize = 18)
#cbar3.ax.set_ylabel(r'$\epsilon_{\rm P}$', fontweight='bold', fontsize = 18)


#theta_tilde_05_values: ['6.22', '10.18', '17.78', '21.64', '9.33', '18.58']
#theta_tilde_02_values: ['3.89', '6.36', '11.11', '13.53', '5.83', '11.61']
#theta_tilde_01_values: ['2.31', '3.79', '6.61', '8.05', '3.47', '6.91']
#theta_tilde_min_05_values: ['12.10', '19.80', '34.58', '42.10', '18.16', '36.14']
#theta_tilde_min_02_values: ['7.56', '12.37', '21.61', '26.31', '11.35', '22.59']
#theta_tilde_min_01_values: ['4.50', '7.36', '12.86', '15.66', '6.75', '13.44']


theta_05_legends = [6.22, 10.18, 9.33]

ax[0, 0].axhline(y=9.33, color='k', linestyle='--', linewidth=1.5)

ax[0, 1].axhline(y=5.83, color='k', linestyle='--', linewidth=1.5)
ax[0, 1].axhline(y=11.61, color='k', linestyle='--', linewidth=1.5)
#ax[0, 1].axhline(y=11.35, color='k', linestyle='-.', linewidth=1.5)

ax[0, 2].axhline(y=3.47, color='k', linestyle='--', linewidth=1.5)
ax[0, 2].axhline(y=6.91, color='k', linestyle='--', linewidth=1.5)
#ax[0, 2].axhline(y=6.75, color='magenta', linestyle='-.', linewidth=1.5)

#theta_tilde_bucket_05_values: ['7.92', '12.96', '22.64', '27.57', '11.89', '23.66', '11.60', '15.79', '19.81', '24.06']
#theta_tilde_bucket_02_values: ['4.95', '8.10', '14.15', '17.23', '7.43', '14.79', '7.25', '9.87', '12.38', '15.04']
#theta_tilde_bucket_01_values: ['2.95', '4.82', '8.42', '10.25', '4.42', '8.80', '4.32', '5.87', '7.37', '8.95']

ax[1, 0].axhline(y=7.92, color='k', linestyle='--', linewidth=1.5)
ax[1, 0].axhline(y=12.96, color='k', linestyle='--', linewidth=1.5)
ax[1, 0].axhline(y=11.60, color='k', linestyle='--', linewidth=1.5)
#ax[1, 0].axhline(y=11.89, color='k', linestyle='-.', linewidth=1.5)

ax[1, 1].axhline(y=4.95, color='k', linestyle='--', linewidth=1.5)
ax[1, 1].axhline(y=8.10, color='k', linestyle='--', linewidth=1.5)
ax[1, 1].axhline(y=7.25, color='k', linestyle='--', linewidth=1.5)
ax[1, 1].axhline(y=9.87, color='k', linestyle='--', linewidth=1.5)
ax[1, 1].axhline(y=12.38, color='k', linestyle='--', linewidth=1.5)
#ax[1, 1].axhline(y=7.43, color='k', linestyle='-.', linewidth=1.5)
#ax[1, 1].axhline(y=14.15, color='k', linestyle='--', linewidth=1.5)

ax[1, 2].axhline(y=2.95, color='k', linestyle='--', linewidth=1.5)
ax[1, 2].axhline(y=4.82, color='k', linestyle='--', linewidth=1.5)
ax[1, 2].axhline(y=8.42, color='k', linestyle='--', linewidth=1.5)
ax[1, 2].axhline(y=10.25, color='k', linestyle='--', linewidth=1.5)
ax[1, 2].axhline(y=4.32, color='k', linestyle='--', linewidth=1.5)
ax[1, 2].axhline(y=5.87, color='k', linestyle='--', linewidth=1.5)
ax[1, 2].axhline(y=7.37, color='k', linestyle='--', linewidth=1.5)
ax[1, 2].axhline(y=8.95, color='k', linestyle='--', linewidth=1.5)
#ax[1, 2].axhline(y=4.42, color='k', linestyle='-.', linewidth=1.5)
#ax[1, 2].axhline(y=8.80, color='k', linestyle='-.', linewidth=1.5)


#ax[2, 0].axhline(y=9.33, color='magenta', linestyle='--', linewidth=1.5)

theta_02_legends = [3.89, 6.36, 11.11, 13.53, 5.83, 11.61]

ax[2, 0].axhline(y=6.22, color='magenta', linestyle='--', linewidth=1.5)
ax[2, 0].axhline(y=10.18, color='magenta', linestyle='--', linewidth=1.5)

ax[2, 1].axhline(y=3.89, color='magenta', linestyle='--', linewidth=1.5)
ax[2, 1].axhline(y=6.36, color='magenta', linestyle='--', linewidth=1.5)
ax[2, 1].axhline(y=11.11, color='magenta', linestyle='--', linewidth=1.5)
#ax[2, 1].axhline(y=7.56, color='magenta', linestyle='-.', linewidth=1.5)
#ax[2, 1].axhline(y=12.37, color='magenta', linestyle='-.', linewidth=1.5)


#ax[2, 1].axhline(y=5.83, color='magenta', linestyle='--', linewidth=1.5)
#ax[2, 1].axhline(y=11.61, color='magenta', linestyle='--', linewidth=1.5)

theta_01_legends = [2.31, 3.79, 6.61, 8.05, 3.47, 6.91]

ax[2, 2].axhline(y=2.31, color='magenta', linestyle='--', linewidth=1.5)
ax[2, 2].axhline(y=3.79, color='magenta', linestyle='--', linewidth=1.5)
ax[2, 2].axhline(y=6.61, color='magenta', linestyle='--', linewidth=1.5)
ax[2, 2].axhline(y=8.05, color='magenta', linestyle='--', linewidth=1.5)
#ax[2, 2].axhline(y=4.50, color='magenta', linestyle='-.', linewidth=1.5)
#ax[2, 2].axhline(y=7.36, color='magenta', linestyle='-.', linewidth=1.5)
#ax[2, 2].axhline(y=12.86, color='magenta', linestyle='-.', linewidth=1.5)


#ax[2, 2].axhline(y=3.47, color='magenta', linestyle='--', linewidth=1.5)
#ax[2, 2].axhline(y=6.91, color='magenta', linestyle='--', linewidth=1.5)
# Out:
# /var/folders/b3/3scq9y017cb0wr4ztdwk3gxm0000gp/T/ipykernel_43535/375598099.py:98: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   fig.tight_layout(pad=1.0, h_pad=1.0, w_pad=1.0)
